# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: torch==1.10.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (1.10.0)
# Requirement already satisfied: rouge_score in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: datasets in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (1.0.2)
# Requirement already satisfied: transformers==4.24.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (4.24.0)
# Requirement already satisfied: transformer-utils in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (0.1.1)
# Requirement already satisfied: packaging in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 6)) (21.3)
# Requirement already satisfied: wandb in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 7)) (0.13.5)
# Requirement already satisfied: pandas in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (1.3.5)
# Requirement already satisfied: numpy in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 10)) (1.21.6)
# Requirement already satisfied: matplotlib in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 11)) (3.5.3)
# Requirement already satisfied: dataclasses in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 12)) (0.6)
# Requirement already satisfied: tqdm in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 13)) (4.64.1)
# Requirement already satisfied: rouge in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from -r requirements.txt (line 14)) (1.0.1)
# Requirement already satisfied: typing-extensions in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from torch==1.10.0->-r requirements.txt (line 1)) (4.4.0)
# Requirement already satisfied: filelock in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from transformers==4.24.0->-r requirements.txt (line 4)) (3.8.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from transformers==4.24.0->-r requirements.txt (line 4)) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from transformers==4.24.0->-r requirements.txt (line 4)) (0.13.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from transformers==4.24.0->-r requirements.txt (line 4)) (2022.10.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from transformers==4.24.0->-r requirements.txt (line 4)) (0.11.0)
# Requirement already satisfied: requests in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from transformers==4.24.0->-r requirements.txt (line 4)) (2.28.1)
# Requirement already satisfied: importlib-metadata in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from transformers==4.24.0->-r requirements.txt (line 4)) (5.1.0)
# Requirement already satisfied: absl-py in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from rouge_score->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: nltk in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from rouge_score->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: six>=1.14.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from rouge_score->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: dill in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from datasets->-r requirements.txt (line 3)) (0.3.4)
# Requirement already satisfied: xxhash in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from datasets->-r requirements.txt (line 3)) (3.1.0)
# Requirement already satisfied: pyarrow>=0.17.1 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from datasets->-r requirements.txt (line 3)) (10.0.1)
# Requirement already satisfied: seaborn in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from transformer-utils->-r requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: colorcet in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from transformer-utils->-r requirements.txt (line 5)) (3.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from packaging->-r requirements.txt (line 6)) (3.0.9)
# Requirement already satisfied: setuptools in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from wandb->-r requirements.txt (line 7)) (65.5.0)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.0,<5,>=3.12.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from wandb->-r requirements.txt (line 7)) (4.21.9)
# Requirement already satisfied: setproctitle in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from wandb->-r requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: shortuuid>=0.5.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from wandb->-r requirements.txt (line 7)) (1.0.11)
# Requirement already satisfied: promise<3,>=2.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from wandb->-r requirements.txt (line 7)) (2.3)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from wandb->-r requirements.txt (line 7)) (0.4.0)
# Requirement already satisfied: psutil>=5.0.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from wandb->-r requirements.txt (line 7)) (5.9.4)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from wandb->-r requirements.txt (line 7)) (1.11.1)
# Requirement already satisfied: pathtools in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from wandb->-r requirements.txt (line 7)) (0.1.2)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from wandb->-r requirements.txt (line 7)) (8.1.3)
# Requirement already satisfied: GitPython>=1.0.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from wandb->-r requirements.txt (line 7)) (3.1.29)
# Requirement already satisfied: pytz>=2017.3 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 8)) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from pandas->-r requirements.txt (line 8)) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 11)) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 11)) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 11)) (9.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from matplotlib->-r requirements.txt (line 11)) (4.38.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from GitPython>=1.0.0->wandb->-r requirements.txt (line 7)) (4.0.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from requests->transformers==4.24.0->-r requirements.txt (line 4)) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from requests->transformers==4.24.0->-r requirements.txt (line 4)) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from requests->transformers==4.24.0->-r requirements.txt (line 4)) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from requests->transformers==4.24.0->-r requirements.txt (line 4)) (3.4)
# Requirement already satisfied: pyct>=0.4.4 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from colorcet->transformer-utils->-r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from importlib-metadata->transformers==4.24.0->-r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: joblib in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from nltk->rouge_score->-r requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->-r requirements.txt (line 7)) (5.0.0)
# Requirement already satisfied: param>=1.7.0 in /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages (from pyct>=0.4.4->colorcet->transformer-utils->-r requirements.txt (line 5)) (1.12.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import datasets
import transformers
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import itertools
import re
from rouge import Rouge
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer,
    DataCollatorForSeq2Seq,
    TrainingArguments,
    DataCollatorForLanguageModeling,
    LineByLineTextDataset,
    EarlyStoppingCallback

)
from datasets import Dataset
from tqdm import tqdm

# %%
model_checkpoints = "gogamza/kobart-base-v2"


tokenizer = AutoTokenizer.from_pretrained(model_checkpoints)
model = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoints)
# Out:
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.

# %%
def preprocess_sentence(sentence):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (..) 제거
    #sentence = re.sub(r'[#@]+[가-힣A-Za-z#]+', ' ', sentence)
    sentence = re.sub(r'[ㄱ-ㅎㅏ-ㅣ]+[/ㄱ-ㅎㅏ-ㅣ]', '', sentence) # 여러개 자음과 모음을 삭제한다.
    sentence = re.sub("[^가-힣a-z0-9#@]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub(r'[" "]+', " ", sentence) # 여러개 공백을 하나의 공백으로 바꿉니다.
    sentence = sentence.strip() # 문장 양쪽 공백 제거
    # 스폐셜 토큰 적용할 거면 여기 위에 영어 외 문자 공백으로 만들때 스폐셜 토큰을 넘어갈 수 있도록 지정해주면된다.
    # 그리고 세번째 정규표현식을 지워야 할 것이다. 
    return sentence

# %%
train_df = pd.read_csv('data/train_total.csv')
val_df = pd.read_csv('data/val_total.csv')

# %%
train_df.head()
# Out:
#                                      Id  \
# 0  fd321028-d5b4-55f7-9e20-2eaa262f9154
# 1  c51be2e4-c8d0-5cea-b1ae-cde1fe8f8ab6
# 2  e90e721f-00d1-5114-aa5d-5f1061472a29
# 3  b215f3a2-d647-59f9-8410-1274ee5edd97
# 4  0bda61b6-1396-5a2a-a049-0b4035e40d59
#
#                                                 Text  \
# 0  ['그럼 날짜는 가격 큰 변동 없으면 6.28-7.13로 확정할까?', '우리 비행...
# 1  ['Kf마스크만 5부제 하는거지?', '응. 면마스크는 아무때나 사도될껀?', '면...
# 2  ['아 근데 케이크 업체들 봤는데 중앙동쪽 거기는 맛만있고 디자인은 그냥그런것같애'...
# 3  ['칫솔사야하는데 쓱으로 살까?', '뭘 칫솔사는것까지 물어보시남ㅋㅋㅋ', '아 그...
# 4  ['잠도안오네ㅐ얼릉 고구마츄 먹고싶단', '그게 그렇게 맛있었어??? 아주 여보 빼...
#
#                                              Summary Category
# 0               비행기 표 가격에 대해 이야기하며, 특가 이벤트를 기다리고 있다.  상거래(쇼핑)
# 1                비염이 있어서 싸게 나온 일회용 부직포 마스크를 사두려고 한다.  상거래(쇼핑)
# 2  케이크 업체 중 중앙동 쪽은 맛만 있고 디자인은 별로고 고잔동 케이크 업체는 배달도...  상거래(쇼핑)
# 3            칫솔을 3개월에 하나씩 바꿔서 왕 칫솔 사러 신세계(쓱) 가자고 했다.  상거래(쇼핑)
# 4                  잠도 안 와서 고구마 말랭이를 양심상 하나만 먹으려고 한다.  상거래(쇼핑)

# %%
# 전체 Text 데이터에 대한 전처리 (1)
train_text = []
train_summary = []

for tt in tqdm(train_df['Text']):
    train_text.append(preprocess_sentence(tt))

for ts in tqdm(train_df['Summary']):
      train_summary.append(preprocess_sentence(ts))
# Out:
# 100%|███████████████████████████████████████████████████████████████| 279992/279992 [00:08<00:00, 33014.84it/s]
# 100%|███████████████████████████████████████████████████████████████| 279992/279992 [00:03<00:00, 92501.40it/s]

# %%
# 전체 Text 데이터에 대한 전처리 (1)
val_text = []
val_summary = []

for vt in tqdm(val_df['Text']):
    val_text.append(preprocess_sentence(vt))

for vs in tqdm(val_df['Summary']):
      val_summary.append(preprocess_sentence(vs))
# Out:
# 100%|█████████████████████████████████████████████████████████████████| 35004/35004 [00:01<00:00, 32627.97it/s]
# 100%|█████████████████████████████████████████████████████████████████| 35004/35004 [00:00<00:00, 84295.66it/s]

# %%
# 전체 Text 데이터에 대한 전처리 (1)
train_Category = []
val_Category= []

for tc in tqdm(train_df['Category']):
    train_Category.append(tc)

for vc in tqdm(val_df['Category']):
    val_Category.append(vc)
# Out:
# 100%|█████████████████████████████████████████████████████████████| 279992/279992 [00:00<00:00, 2768712.52it/s]
# 100%|███████████████████████████████████████████████████████████████| 35004/35004 [00:00<00:00, 2806196.93it/s]

# %%
for i in range(len(val_text)):
    temp_cat = "#"+val_Category[i]+"# "
    val_text[i] = temp_cat+val_text[i]
    
for i in range(len(train_text)):
    temp_cat = "#"+train_Category[i]+"# "
    train_text[i] = temp_cat+train_text[i]

# %%
train_df = pd.DataFrame(zip(train_text,train_summary), columns=['Text', 'Summary'])
val_df = pd.DataFrame(zip(val_text,val_summary), columns=['Text', 'Summary'])

# %%
train_df.head()
# Out:
#                                                 Text  \
# 0  #상거래(쇼핑)# 그럼 날짜는 가격 큰 변동 없으면 6 28 7 13로 확정할까 우...
# 1  #상거래(쇼핑)# kf마스크만 5부제 하는거지 응 면마스크는 아무때나 사도될껀 면마...
# 2  #상거래(쇼핑)# 아 근데 케이크 업체들 봤는데 중앙동쪽 거기는 맛만있고 디자인은 ...
# 3  #상거래(쇼핑)# 칫솔사야하는데 쓱으로 살까 뭘 칫솔사는것까지 물어보시남 아 그 왕...
# 4  #상거래(쇼핑)# 잠도안오네 얼릉 고구마츄 먹고싶단 그게 그렇게 맛있었어 아주 여보...
#
#                                              Summary
# 0                 비행기 표 가격에 대해 이야기하며 특가 이벤트를 기다리고 있다
# 1                 비염이 있어서 싸게 나온 일회용 부직포 마스크를 사두려고 한다
# 2  케이크 업체 중 중앙동 쪽은 맛만 있고 디자인은 별로고 고잔동 케이크 업체는 배달도...
# 3                칫솔을 3개월에 하나씩 바꿔서 왕 칫솔 사러 신세계 가자고 했다
# 4                   잠도 안 와서 고구마 말랭이를 양심상 하나만 먹으려고 한다

# %%
# DF > data Set으로 전환
train_data = Dataset.from_pandas(train_df) 
val_data = Dataset.from_pandas(val_df)
test_samples = Dataset.from_pandas(val_df)

# %%
print(train_data)
print(val_data)
print(test_samples)
# Out:
# Dataset(features: {'Text': Value(dtype='string', id=None), 'Summary': Value(dtype='string', id=None)}, num_rows: 279992)
# Dataset(features: {'Text': Value(dtype='string', id=None), 'Summary': Value(dtype='string', id=None)}, num_rows: 35004)
# Dataset(features: {'Text': Value(dtype='string', id=None), 'Summary': Value(dtype='string', id=None)}, num_rows: 35004)

# %%
max_input = 128
max_target = 32
batch_size = 4
ignore_index = -100# tokenizer.pad_token_id

# %%
 def add_ignored_data(inputs, max_len, ignore_index):
        if len(inputs) < max_len:
            pad = [ignore_index] *(max_len - len(inputs)) # ignore_index즉 -100으로 패딩을 만들 것인데 max_len - lne(inpu)
            inputs = np.concatenate([inputs, pad])
        else:
            inputs = inputs[:max_len]

        return inputs

# %%
def add_padding_data(inputs, max_len):
        pad_index = tokenizer.pad_token_id
        if len(inputs) < max_len:
            pad = [pad_index] *(max_len - len(inputs))
            inputs = np.concatenate([inputs, pad])
        else:
            inputs = inputs[:max_len]

        return inputs

# %%
def preprocess_data(data_to_process):
    label_id= []
    label_ids = []
    dec_input_ids = []
    input_ids = []

    for i in range(len(data_to_process['Text'])):
        input_ids.append(add_padding_data(tokenizer.encode(data_to_process['Text'][i], add_special_tokens=False), max_input))
    for i in range(len(data_to_process['Summary'])):
        label_id.append(tokenizer.encode(data_to_process['Summary'][i]))  
        label_id[i].append(tokenizer.eos_token_id)  
    for i in range(len(data_to_process['Summary'])):  
        dec_input_id = [tokenizer.eos_token_id]
        dec_input_id += label_id[i][:-1]
        dec_input_ids.append(add_padding_data(dec_input_id, max_target))  
    for i in range(len(data_to_process['Summary'])):
        label_ids.append(add_ignored_data(label_id[i], max_target, ignore_index))
   
    return {'input_ids': input_ids,
            'attention_mask' : (np.array(input_ids) != tokenizer.pad_token_id).astype(int),
            'decoder_input_ids': dec_input_ids,
            'decoder_attention_mask': (np.array(dec_input_ids) != tokenizer.pad_token_id).astype(int),
            'labels': label_ids}

# %%
special_words = [
                "#@주소#", "#@이모티콘#", "#@이름#", "#@URL#", "#@소속#",
                "#@기타#", "#@전번#", "#@계정#", "#@url#", "#@번호#", "#@금융#", "#@신원#",
                "#@장소#", "#@시스템#사진#", "#@시스템#동영상#", "#@시스템#기타#", "#@시스템#검색#",
                "#@시스템#지도#", "#@시스템#삭제#", "#@시스템#파일#", "#@시스템#송금#", "#@시스템#",
                "#개인 및 관계#", "#미용과 건강#", "#상거래(쇼핑)#", "#시사/교육#", "#식음료#", 
                "#여가 생활#", "#일과 직업#", "#주거와 생활#", "#행사#",
                ]

tokenizer.add_special_tokens({"additional_special_tokens": special_words})
model.resize_token_embeddings(len(tokenizer))
# Out:
# Embedding(30031, 768)

# %%
train_tokenize_data = train_data.map(preprocess_data, batched = True, remove_columns=['Text', 'Summary'])
val_tokenize_data = val_data.map(preprocess_data, batched = True, remove_columns=['Text', 'Summary'])
# Out:
#   0%|          | 0/280 [00:00<?, ?ba/s]
#   0%|          | 0/36 [00:00<?, ?ba/s]

# %%
    
model.config.max_length = 32 # 256은 쿠다 메모리 오류 생김
model.config.early_stopping = True
model.config.no_repeat_ngram_size = 3
model.config.length_penalty = 2.0
model.config.num_beams = 5

# %%
model.config
# Out:
# BartConfig {
#   "_name_or_path": "gogamza/kobart-base-v2",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartModel"
#   ],
#   "attention_dropout": 0.0,
#   "author": "Heewon Jeon(madjakarta@gmail.com)",
#   "bos_token_id": 1,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.1,
#   "d_model": 768,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 1,
#   "do_blenderbot_90_layernorm": false,
#   "dropout": 0.1,
#   "early_stopping": true,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 1,
#   "extra_pos_embeddings": 2,
#   "force_bos_token_to_be_generated": false,
#   "forced_eos_token_id": 1,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "kobart_version": 2.0,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "length_penalty": 2.0,
#   "max_length": 32,
#   "max_position_embeddings": 1026,
#   "model_type": "bart",
#   "no_repeat_ngram_size": 3,
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_beams": 5,
#   "num_hidden_layers": 6,
#   "pad_token_id": 3,
#   "scale_embedding": false,
#   "static_position_embeddings": false,
#   "tokenizer_class": "PreTrainedTokenizerFast",
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 30031
# }

# %%
rouge = Rouge()
def compute_metrics(pred):
    labels_ids = pred.label_ids
    pred_ids = pred.predictions
    pred_str = tokenizer.batch_decode(pred_ids, skip_special_tokens=True)
    labels_ids[labels_ids == -100] = tokenizer.pad_token_id
    label_str = tokenizer.batch_decode(labels_ids, skip_special_tokens=True)
    
    return rouge.get_scores(pred_str, label_str, avg=True)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="checkpoint/kobart_base_v2_fine_tuning_test",
    num_train_epochs=5,  # demo
    do_train=True,
    do_eval=True,
    per_device_train_batch_size=16,  # demo
    per_device_eval_batch_size=64,
    learning_rate=3e-05,
    weight_decay=0.1,
    #label_smoothing_factor=0.1,
    predict_with_generate=True, # 생성기능을 사용하고 싶다고 지정한다.
    logging_dir="logs2",
    save_total_limit=3,
    load_best_model_at_end = True,
    logging_strategy = 'epoch',
    evaluation_strategy  = 'epoch',
    save_strategy ='epoch'

    #evaluation_strategy = "steps",# step별로 2버 loss가 오르는거 아니면 계속 반복하는듯
    #load_best_model_at_end = True,

)

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer, model=model) # 데이터 일괄 처리?
"""
DataCollatorForSeq2Seq 를 사용하여 예제 배치를 생성 하십시오 . 
또한 일괄 처리에서 가장 긴 요소의 길이로 텍스트와 레이블을 동적으로 채워서 균일한 길이가 되도록 합니다.
tokenizer를 설정하여 함수 에서 텍스트를 채울 수 있지만 padding=True동적 패딩이 더 효율적입니다.
"""
# Out:
# '\nDataCollatorForSeq2Seq 를 사용하여 예제 배치를 생성 하십시오 . \n또한 일괄 처리에서 가장 긴 요소의 길이로 텍스트와 레이블을 동적으로 채워서 균일한 길이가 되도록 합니다.\ntokenizer를 설정하여 함수 에서 텍스트를 채울 수 있지만 padding=True동적 패딩이 더 효율적입니다.\n'

# %%
trainer = Seq2SeqTrainer(
    model, 
    training_args,
    train_dataset=train_tokenize_data,
    eval_dataset=val_tokenize_data,
    data_collator=data_collator,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
   # callbacks = [EarlyStoppingCallback(early_stopping_patience=2)]
)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
trainer.train()
# Out:
# /home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 279992
#   Num Epochs = 5
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 87500
#   Number of trainable parameters = 123883776
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb: Currently logged in as: jx7789. Use `wandb login --relogin` to force relogin
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/home/jx7789/Download/koBART/wandb/run-20221211_162527-376gd7ph</code>
# Syncing run <strong><a href="https://wandb.ai/jx7789/huggingface/runs/376gd7ph" target="_blank">checkpoint/kobart_base_v2_fine_tuning_test</a></strong> to <a href="https://wandb.ai/jx7789/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# You're using a PreTrainedTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='87500' max='87500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [87500/87500 4:32:30, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge-1</th>
#       <th>Rouge-2</th>
#       <th>Rouge-l</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>2.094700</td>
#       <td>1.830840</td>
#       <td>{'r': 0.26448632043977754, 'p': 0.265601466772888, 'f': 0.2565934148989352}</td>
#       <td>{'r': 0.10921027047050748, 'p': 0.11118437358491148, 'f': 0.10610976103374505}</td>
#       <td>{'r': 0.25081498720736306, 'p': 0.25165825107555306, 'f': 0.24321949033626106}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.711500</td>
#       <td>1.773832</td>
#       <td>{'r': 0.2791395882580582, 'p': 0.26485048558066754, 'f': 0.26308731257534196}</td>
#       <td>{'r': 0.11700487360139178, 'p': 0.11219442578439415, 'f': 0.11024312185951424}</td>
#       <td>{'r': 0.2636763118705913, 'p': 0.24996697758273925, 'f': 0.24839765605472136}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.528100</td>
#       <td>1.756691</td>
#       <td>{'r': 0.2781888562100618, 'p': 0.27502900784663464, 'f': 0.2678825475166688}</td>
#       <td>{'r': 0.11624251724834146, 'p': 0.116531329513399, 'f': 0.1120915430580858}</td>
#       <td>{'r': 0.2636100051341486, 'p': 0.2602756645969492, 'f': 0.25366909805982}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.392000</td>
#       <td>1.764348</td>
#       <td>{'r': 0.27705759028063276, 'p': 0.2765490029517691, 'f': 0.26795956016230227}</td>
#       <td>{'r': 0.11583763270925772, 'p': 0.11726059911233941, 'f': 0.11219864864086875}</td>
#       <td>{'r': 0.26248888125558567, 'p': 0.26171621384649046, 'f': 0.2537326442549716}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.292200</td>
#       <td>1.777132</td>
#       <td>{'r': 0.2794292705909282, 'p': 0.274040347439843, 'f': 0.26792529465153037}</td>
#       <td>{'r': 0.11680466699535616, 'p': 0.11590926410874273, 'f': 0.11205052476667915}</td>
#       <td>{'r': 0.2643552172800657, 'p': 0.25886981661844793, 'f': 0.2532767289091419}</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 35004
#   Batch size = 64
# Saving model checkpoint to checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-17500
# Configuration saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-17500/config.json
# Model weights saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-17500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 35004
#   Batch size = 64
# Saving model checkpoint to checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-35000
# Configuration saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-35000/config.json
# Model weights saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-35000/pytorch_model.bin
# tokenizer config file saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-35000/tokenizer_config.json
# Special tokens file saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-35000/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 35004
#   Batch size = 64
# Saving model checkpoint to checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-52500
# Configuration saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-52500/config.json
# Model weights saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-52500/pytorch_model.bin
# tokenizer config file saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-52500/tokenizer_config.json
# Special tokens file saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-52500/special_tokens_map.json
# ***** Running Evaluation *****
#   Num examples = 35004
#   Batch size = 64
# Saving model checkpoint to checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-70000
# Configuration saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-70000/config.json
# Model weights saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-70000/pytorch_model.bin
# tokenizer config file saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-70000/tokenizer_config.json
# Special tokens file saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-70000/special_tokens_map.json
# Deleting older checkpoint [checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-17500] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 35004
#   Batch size = 64
# Saving model checkpoint to checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-87500
# Configuration saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-87500/config.json
# Model weights saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-87500/pytorch_model.bin
# tokenizer config file saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-87500/tokenizer_config.json
# Special tokens file saved in checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-87500/special_tokens_map.json
# Deleting older checkpoint [checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-35000] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from checkpoint/kobart_base_v2_fine_tuning_test/checkpoint-52500 (score: 1.7566906213760376).
# TrainOutput(global_step=87500, training_loss=1.6036812946428571, metrics={'train_runtime': 16354.7749, 'train_samples_per_second': 85.599, 'train_steps_per_second': 5.35, 'total_flos': 1.067008315097088e+17, 'train_loss': 1.6036812946428571, 'epoch': 5.0})

# %%
trainer.evaluate()
# Out:
# ***** Running Evaluation *****
#   Num examples = 35004
#   Batch size = 64
#     <div>
#
#       <progress value='547' max='547' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [547/547 19:05]
#     </div>
# {'eval_loss': 1.7566906213760376,
#  'eval_rouge-1': {'r': 0.2781888562100618,
#   'p': 0.27502900784663464,
#   'f': 0.2678825475166688},
#  'eval_rouge-2': {'r': 0.11624251724834146,
#   'p': 0.116531329513399,
#   'f': 0.1120915430580858},
#  'eval_rouge-l': {'r': 0.2636100051341486,
#   'p': 0.2602756645969492,
#   'f': 0.25366909805982},
#  'eval_runtime': 1154.3236,
#  'eval_samples_per_second': 30.324,
#  'eval_steps_per_second': 0.474,
#  'epoch': 5.0}

# %%
def generate_summary(test_samples, model):

    inputs = tokenizer(
        test_samples["Text"],
        padding="max_length",
        truncation=True,
        max_length=max_target,
        return_tensors="pt",
    )
    input_ids = inputs.input_ids.to(model.device)

    attention_mask = inputs.attention_mask.to(model.device)
    outputs = model.generate(input_ids, num_beams=5, no_repeat_ngram_size=3,
                            attention_mask=attention_mask, 
                            pad_token_id=tokenizer.pad_token_id,
                            bos_token_id=tokenizer.bos_token_id,
                            eos_token_id=tokenizer.eos_token_id,)
    output_str = tokenizer.batch_decode(outputs, skip_special_tokens=True)
    return outputs, output_str

model_before_tuning = AutoModelForSeq2SeqLM.from_pretrained(model_checkpoints)
# Out:
# loading configuration file config.json from cache at /home/jx7789/.cache/huggingface/hub/models--gogamza--kobart-base-v2/snapshots/f9f2ec35d3c32a1ecc7a3281f9626b7ec1913fed/config.json
# You passed along `num_labels=3` with an incompatible id to label map: {'0': 'NEGATIVE', '1': 'POSITIVE'}. The number of labels wil be overwritten to 2.
# Model config BartConfig {
#   "_name_or_path": "gogamza/kobart-base-v2",
#   "activation_dropout": 0.0,
#   "activation_function": "gelu",
#   "add_bias_logits": false,
#   "add_final_layer_norm": false,
#   "architectures": [
#     "BartModel"
#   ],
#   "attention_dropout": 0.0,
#   "author": "Heewon Jeon(madjakarta@gmail.com)",
#   "bos_token_id": 1,
#   "classif_dropout": 0.1,
#   "classifier_dropout": 0.1,
#   "d_model": 768,
#   "decoder_attention_heads": 16,
#   "decoder_ffn_dim": 3072,
#   "decoder_layerdrop": 0.0,
#   "decoder_layers": 6,
#   "decoder_start_token_id": 1,
#   "do_blenderbot_90_layernorm": false,
#   "dropout": 0.1,
#   "encoder_attention_heads": 16,
#   "encoder_ffn_dim": 3072,
#   "encoder_layerdrop": 0.0,
#   "encoder_layers": 6,
#   "eos_token_id": 1,
#   "extra_pos_embeddings": 2,
#   "force_bos_token_to_be_generated": false,
#   "forced_eos_token_id": 1,
#   "gradient_checkpointing": false,
#   "id2label": {
#     "0": "NEGATIVE",
#     "1": "POSITIVE"
#   },
#   "init_std": 0.02,
#   "is_encoder_decoder": true,
#   "kobart_version": 2.0,
#   "label2id": {
#     "NEGATIVE": 0,
#     "POSITIVE": 1
#   },
#   "max_position_embeddings": 1026,
#   "model_type": "bart",
#   "normalize_before": false,
#   "normalize_embedding": true,
#   "num_hidden_layers": 6,
#   "pad_token_id": 3,
#   "scale_embedding": false,
#   "static_position_embeddings": false,
#   "tokenizer_class": "PreTrainedTokenizerFast",
#   "transformers_version": "4.24.0",
#   "use_cache": true,
#   "vocab_size": 30000
# }
#
# loading weights file pytorch_model.bin from cache at /home/jx7789/.cache/huggingface/hub/models--gogamza--kobart-base-v2/snapshots/f9f2ec35d3c32a1ecc7a3281f9626b7ec1913fed/pytorch_model.bin
# All model checkpoint weights were used when initializing BartForConditionalGeneration.
#
# All the weights of BartForConditionalGeneration were initialized from the model checkpoint at gogamza/kobart-base-v2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use BartForConditionalGeneration for predictions without further training.

# %%
#summaries_before_tuning = []
#for test_sample in tqdm(test_samples):
#    summaries_before_tuning.append(generate_summary(test_sample, model_before_tuning)[1])
#summaries_before_tuning = list(itertools.chain(*summaries_before_tuning))    
    
summaries_after_tuning=[]
for test_sample in tqdm(test_samples):
    summaries_after_tuning.append(generate_summary(test_sample, model)[1])
summaries_after_tuning = list(itertools.chain(*summaries_after_tuning))
# Out:
#   0%|                                                                                | 0/35004 [00:00<?, ?it/s]/home/jx7789/anaconda3/envs/dohwan/lib/python3.7/site-packages/transformers/generation_utils.py:1364: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 32 (`self.config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   UserWarning,
# 100%|██████████████████████████████████████████████████████████████████| 35004/35004 [1:15:01<00:00,  7.78it/s]

# %%
rouge.get_scores(summaries_after_tuning, test_samples["Summary"], avg=True)
# Out:
# {'rouge-1': {'r': 0.2406950383954442,
#   'p': 0.2711397263011293,
#   'f': 0.24634545071878675},
#  'rouge-2': {'r': 0.09674010460323362,
#   'p': 0.11166905690425835,
#   'f': 0.09954039699115677},
#  'rouge-l': {'r': 0.22876884860219895,
#   'p': 0.2575379654161758,
#   'f': 0.23404599186957442}}

# %%
for i in range(0, len(summaries_after_tuning), 100):
    print('idx_{} '.format(i))
    #print("Summary before \n", summaries_before_tuning[i])
    print()
    print("Summary after \n", summaries_after_tuning[i])
    print()
    print("Target summary \n", test_samples["Summary"][i])
    print()
    print('Text', test_samples["Text"][i])
    print('-'*100)
    print()
# Out:
# idx_0
#
# Summary after
#  영업팀 과장님이 보내줬는데 팀장님이 해줄지 모르겠고 저번에 부산 갈 때도 숙소로 엄청 싸웠다
#
# Target summary
#  팀장님이 출장 가서 머물 숙소를 계속해서 더 싼 데로 하게 한다고 이야기하고 있다
#
# Text #일과 직업# 웅 영업팀과장님이 보내줬는데 팀장님이 해줄지 모르겠다 저번에 부산갈때도 숙소로 엄청 싸워서 웅 흥 4개월가는거도아니고 3일가는데 좀해주지 거 얼마한다구 내말이 아니 해봤자 3일 다 합해도 몇만원 차이인데 너무해 그때는 2일이었는데도 만원 더 싼데에서 자꾸 자라고 넘 시러 일단
# ----------------------------------------------------------------------------------------------------
#
# idx_100
#
# Summary after
#  본사 직원이 한 달에 한 번씩 온다고 하는데 한 시간 정도 말하는 것 같다
#
# Target summary
#  설빙의 본사 직원이 한 달에 한 번씩 오는데 한 시간 정도 이야기하고 있다
#
# Text #일과 직업# #@소속#본사직원이왓노 누가 아진짜 뭔 일이래 한달에한번씩 온대 근데 한시간 정도 말하는듯 난 면접보러온줄알앗어 오 몰랐네 무슨얘기 지
# ----------------------------------------------------------------------------------------------------
#
# idx_200
#
# Summary after
#  카페를 차리고 주식으로 돈을 벌어와야겠다고 한다
#
# Target summary
#  주식으로 돈을 벌어서 카페를 차리자는 이야기를 하고 있다
#
# Text #일과 직업# 하 카페도 차리자 제발 그니까 내가 잘할게 그니까 주식으로 돈 벌어와야겠네 기승전주식돋니 반박불가 #@이름#를 뛰어넘자 #@이름#부터 중독시켜 인스타올리면 나도인스타맛집
# ----------------------------------------------------------------------------------------------------
#
# idx_300
#
# Summary after
#  자기소개서를 몇 줄이나 썼는지 물어보고 있다
#
# Target summary
#  자기소개서를 몇 줄이나 썼는지 물어보고 취업과 점점 멀어지고 있다
#
# Text #일과 직업# #@이름#야 너 자소서 몇줄이나 썻어 몇줄안댐 지원동기 장점 단점 웅웅 다 다른 문항으로 나누 서 합쳐야 많지 개별로보면 100자 도넘길까말까 그니까 나도그럼 취업과 나는 점점 더 멀어지고있다
# ----------------------------------------------------------------------------------------------------
#
# idx_400
#
# Summary after
#  명함 수거 실적이라 명함이 없어 아빠 명함이라도 받으라고 한다
#
# Target summary
#  명함 수거도 실적이라고 해서 가지고 있는 명함이 있는지 묻는다
#
# Text #일과 직업# 언니 명함없어 명함좀 명함수거도 실적이래 나명함없어이제 옛명함 오케이 아빠꺼라도 받아바
# ----------------------------------------------------------------------------------------------------
#
# idx_500
#
# Summary after
#  수원에 일자리를 구한다고 안 구할 것 같긴 한데 대리님 대기팀으로 넘어갈 것 같다고 한다
#
# Target summary
#  금요일에 대리님 이사님이랑 면담했는데 이사님이 과장 달아야 하지 않겠냐고 해서 대기팀으로 넘어갈 것 같다
#
# Text #일과 직업# 헤어져도 안할듯 그치 수원에 일자리 구한다고 고 안구할거같긴하다 근데 대리님 대기팀으로 넘어갈뜻 이사랑 금욜 면담했대 이사님이 과장 달아야하지 않겠냐면서 와 근데 진심 개호구다 대기팀이랑 수질팀 유지보수 같이 들어가는 사업장 예를들어 대기두명 수질두명 들어갈일 있으면 세명만 넣는거지 대리님이 수질대기 다봐주고 그렇게 돌리고싶나봐 통합인이고
# ----------------------------------------------------------------------------------------------------
#
# idx_600
#
# Summary after
#  면접은 떨어지더라도 서류만 붙어도 내가 뭘라도 사주겠다고 한다
#
# Target summary
#  무료 컨설팅이 완벽해서 서류만 붙어도 뭐라도 사준다고 이야기한다
#
# Text #일과 직업# #@이름# 야 늦게까지 고맙다 면접은 떨어지더라도 머얼 너가더 고생했지 서류만 붙어도 내가 머라도 사줘야겟엉 붙을거야 그런거 안해줘도돼 #@이름# 덕분에 붙겠어 고맙다고마워 내 컨설팅어때 아주좋아 완벽해 공짜컨설팅
# ----------------------------------------------------------------------------------------------------
#
# idx_700
#
# Summary after
#  방학 집중 근로를 신청했는데 되면 월 화 수 목 금 9 6일 해야 하고 시급이 10500원이다
#
# Target summary
#  방학 집중 근로를 신청한 것을 하게 되면 주 중에 9시에서 6시까지 일해야 하는데 시급이 10500원이라 해야 할 것 같다
#
# Text #일과 직업# 방학집중근로 신청했는데 되면 어쩌지 되면 통장으로 들어옴 아니 되면 월화수목금 9 6일해야돼 대신 시급이 10500원 오 개쎈데 그치 해야될각이지
# ----------------------------------------------------------------------------------------------------
#
# idx_800
#
# Summary after
#  10시까지 올린다고 해서 퇴근까지 9시간밖에 안 남았는데 나오라고 했으면 야근 안 할 일인데 괜히 돈만 벌었다
#
# Target summary
#  10시까지 올린다는데 퇴근까지 9시간 밖에 안 남았다며 어제 나오라고 했으면 야근하지 않을 일인데 돈과 시간을 날렸다고 한다
#
# Text #일과 직업# 10시까지 올린다는대 퇴근까지 9시간밖에 안남았다 그냥 어제 나 나오라고 했으면 야근 안할일인데 괜히 돈만 더 날렸죠 돈과 시간을 다 날리는 방법 역시 #@이름# 부업뛸필요 없겠노
# ----------------------------------------------------------------------------------------------------
#
# idx_900
#
# Summary after
#  아직 아르바이트 중인데 열두시 반에 가라고 했다고 하자 오늘 한 사만 원이라고 한다
#
# Target summary
#  아르바이트 한 시간을 다이어리에 적어두라고 권유하고 있다
#
# Text #일과 직업# #@이름#알바와쮸 아직두 알바중이얌 열두시반에가래 개꿀 한시까지로 쳐주는거겠지 오늘한 사만얼마벌었갰당 나는잘모루지 다이어리에 일단 일한만큼만 적어봥 이거막 일케계산할수도있자나 나맨날 일찍보내주면 삼깁분더해서 쓰는데 세시간반 두시간반 합쳐서 여섯시감 뭐이런싣으로 계산할수도있자나 구냥이제부터는 그냥써봐 일한것만
# ----------------------------------------------------------------------------------------------------
#
# idx_1000
#
# Summary after
#  내일 아르바이트 면접을 보러 가야 하는데 집에서 가면 너무 멀어서 못 먹겠다고 한다
#
# Target summary
#  내일 채점 보조 아르바이트 면접이 4시 30분에 있다
#
# Text #일과 직업# 내일 못 먹겠다 나 알바 면접 네시반이얌 그래서 거기 가야되는데 집에서 가면 넘 멀엉 혼자 밥먹고 알바 면접보고 오겠움여 어디 면접 알바면접 뭐 채점보조 알써 잘갔다와
# ----------------------------------------------------------------------------------------------------
#
# idx_1100
#
# Summary after
#  신발도 나름 꿀인데 핸드폰도 할 수 있어서 처음에 포지션을 바꿨을 때 신발을 놓쳤다
#
# Target summary
#  신발 포지션도 좋지만 이건 더 개꿀이라고 한다
#
# Text #일과 직업# 눈치 살살봐가면서 신발도 나름 꿀인데 폰도할수있고 이건 더 대박 그래서 내가 처음에 포지션 바꿧을때 신발놓쳤다 이랬는데 이거 개꿀
# ----------------------------------------------------------------------------------------------------
#
# idx_1200
#
# Summary after
#  아르바이트 하기 싫어서 점심시간 한 시간이 안되는 아홉시부터 다섯시까지 일하는 것에 대해 이야기한다
#
# Target summary
#  아홉 시부터 다섯 시까지 아르바이트하는데 점심시간은 시급도 안 주고 식비도 안 준다며 푸념하고 있다
#
# Text #일과 직업# 언니 나 멍청한짓 한거같다 왜 알바하기싫어서 일하는거 아홉시부터 다섯시까지에 응 점심시간 한시간이 안포함된거였네 일곱시간일하니꺼 근데식비준다는말도없었고 하
# ----------------------------------------------------------------------------------------------------
#
# idx_1300
#
# Summary after
#  하루 빠지고 사 일하면 안 된다고 해서 대표님이 싫어하셨다
#
# Target summary
#  하루 빠진다고 대표님이 싫어해서 그냥 가지 말고 다른 일을 알아본다고 한다
#
# Text #일과 직업# 그때 나 하루빠지고 사일하면안된녀고 불어볼때 대표님이 시러햇러 그런가 그럴거면 나 안뽑는다고 근데 이번엔 다시 가느누입장이니까 이해하지 않을까 그 공백종안 다른일을 구한걸 어떡해 아근대 걍 가지말까봐 나도 다른일 알아볼개 그럼 아뭐하게 모르지 걍 함 찾아보겠네
# ----------------------------------------------------------------------------------------------------
#
# idx_1400
#
# Summary after
#  지금 가면 일곱시에 끝나서 데리러 가겠다고 한다
#
# Target summary
#  속상해서 정시 퇴근하고 일곱 시에 끝나면 데리러 가겠다
#
# Text #일과 직업# 칼퇴할래 속상하니까 알겠어 지금 가면 일곱시에 끝나지 않을까 일곱시에 끝나면 데리러 갈게 시간 봐서 미리 알려줘 그래
# ----------------------------------------------------------------------------------------------------
#
# idx_1500
#
# Summary after
#  너희 회사 잘 되면 커지면 나 고용해달라고 애들이 다 그 말 했다고 하였다
#
# Target summary
#  회사가 커지면 채용해달라고 하니까 애들이 청탁을 한다면서 제발 그렇게 잘 됐으면 좋겠다고 말한다
#
# Text #일과 직업# 너희회사 잘되면 커지면 나고용좀해주라 애들 다 그말함 제발 그렇게되게 잘 됏음 좋겠다 청탁을 나만하는게아니엇군 개웃겨 사람생각하느거 역시 똑가태 개웃기네
# ----------------------------------------------------------------------------------------------------
#
# idx_1600
#
# Summary after
#  공무원 시험을 준비하기 위해 변리사를 준비해 보려고 한다는 이야기를 하고 있다
#
# Target summary
#  얼마 전에 공무원이 되어 변리사 준비를 생각 중인 지인이 인터넷 강의 없이 붙으면 천재로 인정해야 한다
#
# Text #일과 직업# 변리사 준비해볼까 한대 개웃기넼 그래서 내가 학원들어가서 개웃기닺 짴 강의들으라니까 공뭔된지 얼마안되지않음 인강없이 하보려고 이러는거야 인강없이 변리사되면 천재로 인정해야함 이거
# ----------------------------------------------------------------------------------------------------
#
# idx_1700
#
# Summary after
#  자료 기록물 디브이 구축 사업을 신청하려고 이력서를 쓰고 있다
#
# Target summary
#  자료 기록물 데이터베이스 구축 사업 일자리 공고에 이력서를 쓰고 보냈다
#
# Text #일과 직업# 뭐행 나 이력서 쓰고 있으 그렇구낭 자료 기록물 db구축 사업 이거 좀 신청해볼까 싶어서 헐 말만 그럴싸하지 반은 거의 노가다 같나봐 자료책같은거 뜯어서 e북처럼 데이터 옮기는거 계약직이니 그럴수도 9월말까지 계약직 못구하면 그냥 취업할수도 있어 행운을 빌어요 감사합니다 이제 이력서 대강해서 보냈당 수고했으여 좋은결과
# ----------------------------------------------------------------------------------------------------
#
# idx_1800
#
# Summary after
#  사장이 손해 보는 게 없으니 채움 공제를 잘 해주겠다고 하자 그거로 갑질하면 신고한다고 한다
#
# Target summary
#  내일 채움 공제를 신청하러 가면서 떨린다고 하고 연봉이 갑자기 1천만 원 올랐다고 생각하라고 한다
#
# Text #일과 직업# 사장이 내채공 잘 해주겟지 하 떨려 회사입장에선 손해보는거 없으니 해줄겨 근데 그거로 갑질하면 신고 때리고 도망나오면댐 뭐 연봉을 안올려준다거나 그런거 내채공도 해줬는데 연봉을 올려달라고하면안되지 너여기서 2년못버티면 돈안나온다메 막 이런말하면 녹음해서 신고하고 무효처리해서 바로 이직하고 다시 내채공 할수있게 해준대 마자 나도 내채공카페에서 그거후기봄 녹음상시준비해야겟구만 하 지금 말하러 갈거야 묶인다 2년 묶였다 생각하면 우울하니까 그냥 내 연봉이 올랐다 생각하자 지금 니 연봉이 갑자기 1천만원 오른거야 2년하면 2천만원
# ----------------------------------------------------------------------------------------------------
#
# idx_1900
#
# Summary after
#  콜센터 하려면 자격증을 다 따야 하는데 자격증이 없으면 못한다
#
# Target summary
#  자격증을 따는 것 자체는 안 어렵고 콜센터를 하려면 자격증을 따야 한다
#
# Text #일과 직업# 콜센터하려면 자격증 다따야대 아니면 못해 아아 말햇던거같네 근데 막 어렵지 않은 자격증이라고 햇던거같아서 까머금 웅 자격증 자체는 안어려웡 글쿠만
# ----------------------------------------------------------------------------------------------------
#
# idx_2000
#
# Summary after
#  인턴인데 아직 발표를 안 해서 다들 똑같은 입장이라고 한다
#
# Target summary
#  인턴 발표가 나질 않는데 포스팅은 올라와 의문을 갖는다
#
# Text #일과 직업# #@시스템#사진# 근데아직도 발표안함 다들똑같은입장 강 안했나봄 발표를 왜 안하지 인턴인데 그니까 근데 #@기타# 포스팅은 계속 올라놈 그뭐지 담당자가다를듯 포스팅올리눈사람따로 에휴 언제까지 기다려
# ----------------------------------------------------------------------------------------------------
#
# idx_2100
#
# Summary after
#  10 12시 점검 시간이 굉장히 아쉽고 주로 이 시간에 하는데 계속 엑셀로만 편집 중이다
#
# Target summary
#  10 12시에 주로 하는데 점검 시간이라 아쉽다며 컴플레인 메일을 보내라 한다
#
# Text #일과 직업# 10 12시 점검시간 굉장히 아쉽 난 주로 이시간에 하는데 그래서 계속 엑셀로만 편집중 그치 나두 그 생각 함 그 시간이 젤 많이 하는 시간인디 니가 컴플레인 메일 보냌 진짜 점검해 구지 괜찮소 근데 점검중이면 해당 페이지도 안열리던가 해여되는데 또 열림 엥 안 열리는 거 아녀 열리긴해
# ----------------------------------------------------------------------------------------------------
#
# idx_2200
#
# Summary after
#  오늘은 실장과 팀장 둘 다 안 나왔다고 하자 자기도 오늘 나름 꿀 시간이라며 빨리 퇴근하라고 한다
#
# Target summary
#  실장과 팀장이 둘 다 안 나와서 일하기 좋다
#
# Text #일과 직업# 나는 오늘 나름 꿀 나 오늘 완전 꿀 실장 팀장 둘다 안나옴 씐나 나도 오늘 나름 꿀 시간 개 빨리감 빨리 퇴근하고시퍼 너 내일이 마지막이야 웅 개조아
# ----------------------------------------------------------------------------------------------------
#
# idx_2300
#
# Summary after
#  신입들과 남자 과장이랑 사수한테 불려나가서 담배 피우러 첫 출근이라고 한다
#
# Target summary
#  신입들과 남자 과장이 이야기하고 담배 피우러 사수한테 불려 나갔고 남자들은 그러면서 친해진다
#
# Text #일과 직업# 신입들이랑 남자과장이랑 사수한테 불려나감 오늘 업무첫날아니야 덜덜 얘기하고 담배피러 첫출근인데 웬 담배 신입이 과장앞에서 담배를 피울수있어 남자들은 그러면서 친해지거든
# ----------------------------------------------------------------------------------------------------
#
# idx_2400
#
# Summary after
#  방금 전화가 왔는데 오후 5시부터 술집 한 테이블 밖에 안 왔다고 시급 만 원 주고 장사하는 사람이라고 한다
#
# Target summary
#  코로나 때문에 나주에 있는 술집에 오후 5시부터 손님이 없어 시급 1만 원을 받고 일이 끝났다는 이야기를 한다
#
# Text #일과 직업# #@이름#이 방금 전화왔는데 개웃겨 오후5시부터 술집 한테이블 밖에 안왔다고 걍 시급만원주고 장사접자고해서 끝개웃겨 한시간 한거지 근데 그거 한시간 하려고 나주간거면 억울하겠는데 나주는 덜하나 코로나 #@이름#이집 놀러가고프다 헤헤 오늘#@이름#이밖에 없는데 근데 나주 지금 깜깜이들 많아서 깜깜이들이 뭔가유 경로모르는애들 감염경로
# ----------------------------------------------------------------------------------------------------
#
# idx_2500
#
# Summary after
#  잡코리아에서 합격 자기소개서를 볼 수 있다
#
# Target summary
#  합격 자기소개서 보다가 너네 학교 사람이 쓴 거 봤다고 하니 어디서 봤냐고 하고 잡코리아에서 봤다고 한다
#
# Text #일과 직업# #@이름#야 나합격자소서보다가 너네학교사람이 쓴거봄 오 어디서 #@시스템#사진# 잡코리아에서 합격자소서볼수있는데 너네학교도 지방4년으로나오는구낭 지방에있으니까 그렇군
# ----------------------------------------------------------------------------------------------------
#
# idx_2600
#
# Summary after
#  에메필 브라가 너무 작아서 컵이 올라간다고 하고 로켓 발사라고 한다
#
# Target summary
#  브라가 너무 작아서 잘 맞는 인생 브라를 추천해 주었다
#
# Text #주거와 생활# 브라한게 넘나작은것 에메필 브라해 컵이 올라간다 진짜 인생 브라 로켓발사인것 에메필 정말 친구씨컵인애가 했었는데 나는 잘맞더라구 초모리랑 비무네 하루종일 가슴만범
# ----------------------------------------------------------------------------------------------------
#
# idx_2700
#
# Summary after
#  끝나고 코인 노래방에 가기로 했다
#
# Target summary
#  끝나고 코인 노래방에 가고 싶은데 비 오니깐 바로 집으로 가는 게 나을 거 같다고 물으니 체력이 있다면 상관없다고 한다
#
# Text #주거와 생활# 하 끝나고 코노 오바겠지 비오니까 바로집가는게 낫겠찌 체력이있다면뭐 상관업찌 그치 휴 기고싶어 와지금왔는데센터 바지 아랫부분다젖고 신발고댜젖곸 미쳐씀 지금여기는 멈췄어
# ----------------------------------------------------------------------------------------------------
#
# idx_2800
#
# Summary after
#  감귤청이 차갑길래 바로 옆에 마카롱을 놔서 집으로 가고 있다
#
# Target summary
#  집에 가는 길에 감귤청이 차가워서 바로 옆에 마카롱을 놨다고 이야기하고 있다
#
# Text #주거와 생활# 감귤청이 차갑길래 바로옆에 마카롱을놨어 헐 #@이름#집으로고고 #@이모티콘# 곰방갈수있을그야 집도착햇어 지금막도착 나는멀엇지 #@이름#도금방가지
# ----------------------------------------------------------------------------------------------------
#
# idx_2900
#
# Summary after
#  아저씨가 이대역에서 안 내려줘서 혼나야겠다고 한다
#
# Target summary
#  버스 아저씨가 이대역 버스 정류장에서 내려주지 않았다
#
# Text #주거와 생활# 데 웅웅 아저씨가 이대역에서 안내려줌 여기도 버정이 바뀐건가 아니 아저씨 좀 혼나야게네 #@이모티콘# 앜 도로가 공사해서일까 혼란해
# ----------------------------------------------------------------------------------------------------
#
# idx_3000
#
# Summary after
#  다이아 바로 옆 양쪽 부분이 리본처럼 접히는 거 말고 일자로 해준다고 한다
#
# Target summary
#  다이아 옆을 리본처럼 접히는 것 말고 일자로 해 달라고 했다
#
# Text #주거와 생활# 다이아바로옆 양쪽부분 평평한건없어여 일자를 좋아하면 저렇게 리본처럼 접히는거말구 일자로 해준데 그얘기야 일자가조아여 알았어 리본처럼접히는게머지 넌 몰라
# ----------------------------------------------------------------------------------------------------
#
# idx_3100
#
# Summary after
#  장학금을 못 받아서 학자금 대출을 받아야 한다
#
# Target summary
#  나는 국가장학금 신청이 안 되어서 학자금 대출을 받아야 한다
#
# Text #주거와 생활# 나 학자금 대출 받아야함 국장 신청된줄 알았더니 안도 서 왜안돼 장학금 못받음 #@기타# 저번 햇잖아 그치 근데 안되있더라고 그래서 2차때 구제신청 해얃해 오바 개오바 구래서 #@이름#대출 쓰기로 함 300빌려준뎅
# ----------------------------------------------------------------------------------------------------
#
# idx_3200
#
# Summary after
#  서류를 인쇄해서 사인해서 보내야 하는지에 대해 이야기한다
#
# Target summary
#  밑에 보면 서명하는 데가 있는데 인쇄해서 서명을 해서 보내야 하는 거냐고 하자 인터넷으로 등록하고 또 보내냐고 한다
#
# Text #주거와 생활# 근데 밑에 보면 싸인하는거 있는데 인쇄해서 싸인해서 보내야되는건가 머야 저걸 또 보내야해 나도 모르겟어 서류들이랑 저거 프린트 해서 보내는거 같기는한뎅 머야 인터넷으로 등록하고 또보내 혹시 모르니까 보내는게 낫겟지 흠 그래야하나
# ----------------------------------------------------------------------------------------------------
#
# idx_3300
#
# Summary after
#  문을 안 열어서 현관에서 낑낑거렸다
#
# Target summary
#  강아지처럼 낑낑 댄 것에 대해 문이 안 열려서 현관에서 낑낑댔다고 말한다
#
# Text #주거와 생활# 낑낑 대는게 강쥐처럼 낑낑 아아 내가 엉 문안열려서 현관서 깡낑 거렷다고 아아 낑낑댄다의 낑낑 아 이해함
# ----------------------------------------------------------------------------------------------------
#
# idx_3400
#
# Summary after
#  생각해 보니 빨간색이 있어서 빨간색으로 하기로 했다
#
# Target summary
#  빨간색 옷이 있어서 빨간색을 하기로 했다
#
# Text #주거와 생활# 진짜 나옷없나보다 야 야근데 나도 생각해보니 빨간색 없어 빨간색있어 오 야 너 그럼 빨간색해
# ----------------------------------------------------------------------------------------------------
#
# idx_3500
#
# Summary after
#  체크카드는 한도가 있고 백 이상은 제한이 있다
#
# Target summary
#  자기 경험 상 체크카드 한도가 백만 원 이상은 될 거라고 말하자 한 번 노는 것에 십만 원도 긁어본 적이 없다고 말한다
#
# Text #주거와 생활# 한도가잇나카드에근데 쪕 체카도 제한 이쓸걸 그르냐 체크는그렇구먼 한도 백이상은도 왜냐면 내가그이상써본거가터 #@이모티콘# 뱅기값이구먼 난 한번에 노는거에 십마넌도 못 긁어봤어 그러치 누가그렇게긁어 타패살면인정 꺄륵 숙소나 호텔잡을때 긁자너
# ----------------------------------------------------------------------------------------------------
#
# idx_3600
#
# Summary after
#  핸드폰 카메라가 좋아졌어도 아직까지는 디에스엘알을 따라잡지는 못하겠다
#
# Target summary
#  핸드폰 카메라와 디에스엘알의 렌즈 성능에 대해 비교한다
#
# Text #주거와 생활# 폰카메라가 좋아졌어도 아직까지는 dslr을 따라잡지는 못하겠지 응 그렇더라 디세랄 쓰는 오빠 말로는 그렇대 내 경험상은 아니야 우아 그렇구나 언제쯤 따라잡을까 궁금해지네요홓홓 그렇구나 그렇지만 사진 욕심 없는 언니는 지금 쓰는 정도로도 딱 좋은 거 같아
# ----------------------------------------------------------------------------------------------------
#
# idx_3700
#
# Summary after
#  완행을 탔어야 했는데 못 탔고 역마다 서는 중이다
#
# Target summary
#  급행을 탔어야 했는데 못 타고 완행 타서 역마다 다 서는 중이며 이제 군포라고 말한다
#
# Text #주거와 생활# 나 급행을 탔어야했는데 못탔어 완행탔겠네 그럼 역마다 아주 다 서는중 완행의 길이란 그런것 걍 기다렸다 급행을 탈걸그랬나봐 지금은 어딘데 아직멀었어 이제군포 역마다 다선다 진짜 세월아 네월아야 1호선의 맛이다 그게 어쩔수 없어 1호선은
# ----------------------------------------------------------------------------------------------------
#
# idx_3800
#
# Summary after
#  과실이 많이 나와도 보험처리가 하기 싫다
#
# Target summary
#  상대방 과실이 많아서 비용을 더 많이 내야 하니까 보험처리하기가 싫은 거다
#
# Text #주거와 생활# 마니나와도 과실이 우리가 못나와도 7 3이라서 그쪽이 많이내야하니까 보험처리하기싫은거야 응싫겟지 우리가고친다하면 7 3이란게 그쪽이랑 우리랑 고친거다합쳐서 다고쳐줘야하니깐 7 3으로나누는거라 자기차고치는거많이나와도 싫징
# ----------------------------------------------------------------------------------------------------
#
# idx_3900
#
# Summary after
#  화장실 배너를 만들려면 샘플 선택한 것을 알려주고 도면을 받아야 한다
#
# Target summary
#  배너도 만들어야 하니 화장실 시트지를 선택해달라고 하면서 선택한 샘플을 알려주고 도면을 받아야 한다고 말한다
#
# Text #주거와 생활# 화장실 시트지 빨리 선택해주세요 나 배너도 만들어야해요 웅 #@시스템#사진# 샘플 선택한거 알려주고 도면 받아야함 아하
# ----------------------------------------------------------------------------------------------------
#
# idx_4000
#
# Summary after
#  스를 몇 년 만에 가서 설렌다고 하였다
#
# Target summary
#  고등학교 이후로 빕스를 간 적이 없어서 오랜만에 갈 생각하니 설렌다고 얘기했다
#
# Text #주거와 생활# 빖스를몇년만에가서 설렌다 심각한애슐리덕구여꾸만 난니가부페덕구인줄알앗는데 취향이확고했었어 빕스는 고딩때이후로안간거같아 애슐리카드를보여주던#@이름#이잊지모태 내카드에 천얼마밖에없어써 그거밖에안모여써 하 실망이다
# ----------------------------------------------------------------------------------------------------
#
# idx_4100
#
# Summary after
#  친구들이 오늘 하늘이 파랗고 바단 줄 알았는데 너무 좋다고 한다
#
# Target summary
#  오늘 하늘이 바다처럼 파랗고 날씨가 너무 좋다
#
# Text #주거와 생활# 칭구들 오늘 날씨 초대박아니냐 하늘 개 파래 바단줄 어 날씨 넘 좋아 어케 맞아 오늘 날씨 개좋아 낼도 좋기를
# ----------------------------------------------------------------------------------------------------
#
# idx_4200
#
# Summary after
#  일 다닐 때 매는 크로스 가방은 놀러 다니기엔 별로다
#
# Target summary
#  자신도 일을 다닐 때 매는 가방 디자인인데 그 디자인으로 하나 사 주면 좋을 것 같다고 이야기한다
#
# Text #주거와 생활# 다저런가방은 그냥놀러다니기엔 별론가봐 그치 너무큼 그래서 일다닐때매는 크로스나 #@시스템#사진# 이런거 저런디자인 하나있거든 그거두개매고다니는데 저거하나사주면 좋을듯
# ----------------------------------------------------------------------------------------------------
#
# idx_4300
#
# Summary after
#  오늘 서울에 가지 말라고 한 듯 거의 다 2층 버스인데 기대했는데 넣어두라고 한다
#
# Target summary
#  2층 버스가 아니라서 실망하자 다음 주에 2층 버스를 타고 사당에 가자고 하였다
#
# Text #주거와 생활# 열라짱나 2층버스아냐 당신 오늘 서울 가지 말라고 한듯 거의다 2층이던데 기대했는데 넣어둬 나랑 있어야 했는뎅 담주에 2충버스타고 사당가자 봐서 그랭 쉬어 잘갔다오아 오키 #@시스템#사진#
# ----------------------------------------------------------------------------------------------------
#
# idx_4400
#
# Summary after
#  내리자마자 비가 왔는데 지금 비가 안 온다
#
# Target summary
#  내리자마자 비가 많이 왔는데 못 봤다고 한다
#
# Text #주거와 생활# 내리자마자 비옴 비 안 오는데 아냐 비왓어 지금 그쳤나 아까는 왓어 지금 비 안 와 나는 비 오는 거 못 봤어 비 엄청 많이 왔어
# ----------------------------------------------------------------------------------------------------
#
# idx_4500
#
# Summary after
#  내일 일단 가보려고 하는데 1번은 전포동이고 2번은 부평이다
#
# Target summary
#  두 개가 연락이 돼서 전포동과 부전동에 가보려는데 위치도 괜찮고 해서 같이 가달라고 했다
#
# Text #주거와 생활# 내일 일단 가보려고 #@시스템#사진# 여기 두개 연락 되서리 오 옹키옹키 올 1번 좋은데 1번은 전포동 2번은 부전동 닥 1번 #@시스템#사진# 위치도 괜춘 오키오키 내일 같이 가주실 아님 언니아랑 형부 쉬어서 같이 가준다는데
# ----------------------------------------------------------------------------------------------------
#
# idx_4600
#
# Summary after
#  이번 주 토요일 일요일 오사카 날씨가 흐리고 50 안 올 것 같으니 우산 하나씩 챙기라고 한다
#
# Target summary
#  오사카에 비가 온다고 해서 우산을 챙기고 괜찮은 우비를 사가자고 한다
#
# Text #주거와 생활# 이번주 토 일요일 오사카 날씨가 흐림 때때로 비야 50 안올거얌 그럼 혹시모르니 우산 조그만거 하나씩 챙기쟈 우비를 챙겨야하나 뭐 비오면 여유롭게 있다오면되겠지 우비는 가서 살까 월요일날 유니버셜 갈때 비오면 진짜 절망인데 월요일은 유니버셜이니까 비오면 우비쓰는걸로 #@이름#이는 우비 미리 사가래 완전 괜찮은걸로 우비 괜찮은게 어떤거지 #@이름#이는 바지까지 같이 입는걸 추천해줬어 #@시스템#사진# 저렇게 둘이 입은 커플이 있었는데 꽁냥 너무 귀여웠대 근데 자기네는 비닐 쪼가리 우비라 너무 형편없었대
# ----------------------------------------------------------------------------------------------------
#
# idx_4700
#
# Summary after
#  운전면허를 제일 마지막으로 땄던 것 같다
#
# Target summary
#  세 명 중에 내가 제일 마지막으로 운전면허를 땄다며 장롱면허지만 면허가 있다고 하고 있다
#
# Text #주거와 생활# 운전 면허 땄었나 응 내가 젤 마지막으로 땄을걸 울 셋 중에 맞아 그랬던거 같다 #@이름# 은 20살때 바로 땄다고 했으니까 나두 그렇구 맞아 장롱면허지만 있긴하지 후후
# ----------------------------------------------------------------------------------------------------
#
# idx_4800
#
# Summary after
#  인테리어 좋은 신축도 아니고 집주인 있는 그런 신축이라 초라한 것 같아서 제일 걸린다
#
# Target summary
#  집주인 있는 신축이라 초라한 것 같아서 싫다고 하니 자취생들 다 비슷하다고 한다
#
# Text #주거와 생활# 인테리어 좋은 신축도 아니고 집주인 있는 그런 신축이고 그래서 초라한거 같아서 그게 제일 걸려 흠 자기 집아니자낰 모어땤 자취생들 집이 다 비슷할것같은데 주인은 아니지만 자기는 자취안해서 몰라 잉 머어때
# ----------------------------------------------------------------------------------------------------
#
# idx_4900
#
# Summary after
#  부동산은 시흥 3동 가로정비 사업이 생각나서 찾아봤더니 1억 5천만 원이었다
#
# Target summary
#  부동산 가격이 많이 오른 것에 대해 이야기를 나눈다
#
# Text #주거와 생활# 부업은 거기까지만 부업은 할만큼한 해야해요 네 부동산은 시흥3동 가로정비사업 생각나서 오랜만에 찾아봤더니 1억5천이었던집이 3억5천 역시 먼저 선택하는자가 이기는 게임이네요 그니까요 지나갈때마다 여기는 아파트로 되면 괜찮겠다했더니 역시나 역시 이젠 안 오르는 곳이 더 이상한 듯 청약을 기다리는 나로서는 그림의 떡이지만 얼른 하나 사요 더 오르면 이젠 진짜 못살 가격될듯 10평도 안되는데 금천구가 3 5억이라니 서울에서 3억 집은 지하철안다니는 지역에나 있는 것 같아요 헉 10평도 안되는 집 진짜 이젠 3억도 우스워졌나봐요 그니까요
# ----------------------------------------------------------------------------------------------------
#
# idx_5000
#
# Summary after
#  교회 앞에 배추를 조그맣게 해놨는데 농약을 안 쳐서 벌레가 생겼다
#
# Target summary
#  엄마와 아빠가 심은 배추에 대해 이야기한다
#
# Text #주거와 생활# #@시스템#사진# 엄빠가 심은 배추 대박 밭두 잇냐 교회앞에 조그맣게 해놧는데 농약을 안쳐서 벌레가 엄청먹어서 막걸리뿌렷어 민간요법 저걸로 김장하면 되겠다 야 요즘 배추값 금값이여 두포기에 3마넌인가
# ----------------------------------------------------------------------------------------------------
#
# idx_5100
#
# Summary after
#  적금을 이미 넣고 있다며 북마크 한 것을 보라고 한다
#
# Target summary
#  이미 적금을 넣고 있어서 저거 할 돈이 없다
#
# Text #주거와 생활# 내가 북마크 한거 봐바 적금 개이득이야 왜 톡안바 봤어 이돼지야 적금 이미 넣고있느넉있어 하라고 저거 도넚어 돈없다고 너가 돈주더가
# ----------------------------------------------------------------------------------------------------
#
# idx_5200
#
# Summary after
#  요즘 커피 웍스가 많이 보이는데 중상동 지나가는데 두세 개는 본 것 같다
#
# Target summary
#  갑자기 카페가 많이 생겨서 차 타고 중상동 지나가다가 커피 웍스를 두세 개 정도 봤고 도당동에도 메가 커피가 생겼다
#
# Text #주거와 생활# 요즘 커피 웍슨가 그거 많 보이더라 차타고 중상동 지나가는데 두세개는 본듯 그게 모야 카페 개많이 생겼어 갑자기 카페 진짜 마니 생기는듯 도당동에만 해도 메가커피도 생기고 야 메가커피가 대박인듯 진짜 울나라는 뭐 하나 뜨면 질릴때까지 하는 거 같앜
# ----------------------------------------------------------------------------------------------------
#
# idx_5300
#
# Summary after
#  하기 싫으면 여기서 타자 못 친다고 하니 살살하면 괜찮을 것 같다고 한다
#
# Target summary
#  키패드 덮개가 없어서 타자를 못 치기 때문에 덮개를 사야 한다고 이야기한다
#
# Text #주거와 생활# 하기싫으면 글써 여기서 타자 못친당 헉 잠깐은 갠찮을걸 살살하면괜찮겟지 너는 키패드도 있자나 너 키패드 안들고왓어 키패드 맞나 그 덮개 아 키패드덮개 그거 사야해 너도 사
# ----------------------------------------------------------------------------------------------------
#
# idx_5400
#
# Summary after
#  일산 1인가구 세대주여도 건강보험료를 내는 건 아빠 이름으로 되어있다
#
# Target summary
#  1인 가구 세대주여도 건강 보험료는 아빠 이름으로 되어 있고 강원도여서 4인 가족으로 받고 쓰는 것도 강원도만 된다고 한다
#
# Text #주거와 생활# 여시댓글 봣는데 내가 일산 1인가구 세대주여도 건보료 내는 건 아빠이름으로 돼있어서 4인가족으로 받는거고 그거 쓰는 것도 아빠가 강원도로 돼있어서 강원도만 맞아 나도안돼 피보험자라서 #@기타# 오늘 동사무소에 노인분들 줄 준내 길엇음 지원금때매 하 기준이 너무하군 그니까 고양시 지원금 타러 가야겠다 모레
# ----------------------------------------------------------------------------------------------------
#
# idx_5500
#
# Summary after
#  지갑을 받으러 가는 곳이 어딘지 봤냐고 하자 종이에 써있다고 한다
#
# Target summary
#  지갑을 받으러 가는 곳이 찾으러 가는 곳과 바로 옆으로 비슷하다
#
# Text #주거와 생활# 언니 지갑 받으러 가는곳 어딘지 봤어 응 그 종이에 써이 # 써있엉 찾으러 가는것 지슷한가 해서 물어본간뎅 그건 안봤나보군 힣 아 비슷해 바로 옆인가 그랬던거같아 어홍 다행이군 마쟈마쟈
# ----------------------------------------------------------------------------------------------------
#
# idx_5600
#
# Summary after
#  아이폰만 쓰던 나에게 갤럭시 핸드폰이 알차게 꾸몄다
#
# Target summary
#  갤럭시 핸드폰으로 바꾸고 폰트도 구매해서 알차게 꾸미고 있다
#
# Text #주거와 생활# 핸드폰적응중 좋지 개좋다 아이폰만 쓰던나에게 갤럭시란 신세계구만 폰도 알차게 꾸밈 오 갤럭시스토어에 뭐 많이 파는데 폰트같은거 안그래도 폰트도 돈주고삿어 3500 냥
# ----------------------------------------------------------------------------------------------------
#
# idx_5700
#
# Summary after
#  어제부터 오늘까지 춥지만 낮에는 생각보다 좋아 보인다
#
# Target summary
#  해 있을 때는 괜찮지만 칼바람이 불어서 춥다고 이야기한다
#
# Text #주거와 생활# 나만 추워서 오들도들 중이야 진짜 춥더라 어제부터 오늘 그래도 낮에는 생각보다 좋아보이더라 지금 나눈 춥지만 맞아 해있을땐 갠차는제 해지면 #@기타# 어제 경안천 걷는데 겁니 칼바람이 쌩쌩 햇빛에 있어야 들춥나바
# ----------------------------------------------------------------------------------------------------
#
# idx_5800
#
# Summary after
#  운전 소질이 있는데 아직 엉성해서 약간 늘은 것 같다고 한다
#
# Target summary
#  운전 실력이 저번에 비해서 좀 나아진 거 같다고 하고 있다
#
# Text #주거와 생활# 운전잘햇냥 그렇다 약간늘은거같아 오진짜 소질잇당 그렇다 아냐근데아직 엉성해서 저번보다는점나아졌다정도야 그래도 조금씩나아지면되는거지뭐 두어달지나면 #@이름#태우고 계양역까진가능할듯 맞아 히히
# ----------------------------------------------------------------------------------------------------
#
# idx_5900
#
# Summary after
#  향수도 다 떨어져가는데 사고 싶은 게 너무 많아서 블루벨을 사려고 한다
#
# Target summary
#  사고 싶은 것이 너무 많아서 나중에 근로 장려금으로 생활하려고 한다
#
# Text #주거와 생활# 사고 싶은거 넘 많다 꺄 흑 향수도 다떨어져가는데 블루벨 사야징 희희 이제 그거 없어면 어떻세 하나 막막해 그때부턴 근로장려금이 우리를 먹여살려줄거야 윽 그 다음에는 슬프네 청년수당 흑 후 그때는 그때의 #@이름#이 해결할거애 맞아 넘 설렌당 넘 조쿤
# ----------------------------------------------------------------------------------------------------
#
# idx_6000
#
# Summary after
#  주식에 돈을 다 물려서 생활비가 제로에 수렴했다
#
# Target summary
#  주식에 돈이 다 물려서 생활비가 없다고 하니 비상금을 쓰라고 하니 그건 부모님 생신이나 어버이날에 써야 한다고 안된다고 한다
#
# Text #주거와 생활# 지금 주식에 돈 다 물려서 생활비 제로에 수렴함 흙흙 알바비도 거의다 거지돼써 신카 할부로 나가는제 이게 뭐람 울디마 바버야 집에 비상금 잇자나 앙대 그건 앵대 엄빠 생일 or 어버이날에 써야한다고
# ----------------------------------------------------------------------------------------------------
#
# idx_6100
#
# Summary after
#  스타벅스에 왔는데 사람이 엄청 많아서 자리를 찾아보려 한다
#
# Target summary
#  이제 카페 가서 놀려고 스타벅스 왔는데 사람이 너무 많고 다 공부한다고 자리 찾아봐야 한다고 하니 난 공부 한다고 한다
#
# Text #주거와 생활# 이제 카페가서 놀아야디 공뷰하라구 스벅왓는데 사람 엄청많아 다 공부하네 자리찾아바야디 난 공부한당 우웅 열공
# ----------------------------------------------------------------------------------------------------
#
# idx_6200
#
# Summary after
#  11평은 너무 좁을 것 같고 화장실과 실면적이 8 9이다
#
# Target summary
#  화장실과 주방을 다 합쳐서 11평일 것이고 자리싸움이 날 것 같다
#
# Text #주거와 생활# 11평은 너무 좁겠지 실면적 인가 그게 11이면 넓은거 아닐가 막 8 9 이러더넫 투름 맞냐노 화장실이랑 주방 다 합쳐서 11일거 아녀 쌈나겠너 내자리라노 내가 먼저 발 뻗었다
# ----------------------------------------------------------------------------------------------------
#
# idx_6300
#
# Summary after
#  찜질방에서 옷을 갈아입고 달걀을 먹고 앉아서 수다를 떨고 싶다
#
# Target summary
#  찜질방에서 음식을 먹으며 몸을 찜질하고 탕에 들어가고 싶다
#
# Text #주거와 생활# 때밀고싶어 찜질방에서 옷 갈아입고 달걀먹고 앉아서 수다떨고싶어 뜨끈뜨끈한곳에서 몸지지고싶어 #@기타#탕에 들어가서 익히고싶다 아 거기서 아이스녹차 조져야한다고
# ----------------------------------------------------------------------------------------------------
#
# idx_6400
#
# Summary after
#  홍콩에서 누가 네이버 아이디로 로그인했는데 해외 아이피 차단 안 해놔서 해외에서 접속 불가해놓으라고 한다
#
# Target summary
#  요즘 계속 홍콩에서 누가 내 네이버 아이디로 로그인해서 해외 접속 불가 해놨는데도 계속 그래서 네이버에 문의 메일을 해봐야겠다
#
# Text #주거와 생활# 홍콩에서 누가 내 네이버 아이디 로그인함 요즘 계속 이러네 해외 아이피차단 왜 안 해놈 해외에서 접속 불가 해놓으삼 #@기타# 해놨는데 이러네 요즘 왜 이래 네이버에 문의메일 해보삼 차단해놨는데 접속된다구 알써 내 거 털어도 뭐 없는데 쩝
# ----------------------------------------------------------------------------------------------------
#
# idx_6500
#
# Summary after
#  다음에 핸드폰을 바꿀 때 어떤 핸드폰으로 바꿔야 할지 추천해달라고 한다
#
# Target summary
#  다음에 핸드폰을 바꿀 때 무엇으로 바꿔야 할지에 대해 이야기하고 있다
#
# Text #주거와 생활# 님들 나 다음에 폰 바꿀 때 뭘로 바꿔야 할지 추천 좀 흠 #@소속#폰이 좋을 것 같다 노트 10 나 20 어때 저는 갤럭시노트20 울트라가 좋은거 같아요 근데 가성비를 따져야 함 너무 비싸 하긴 ram이 12gb나 되는데 성능 보면 안비쌀수가 없지 울트라는 카메라가 튀어나온게 단점이라 추천 안해
# ----------------------------------------------------------------------------------------------------
#
# idx_6600
#
# Summary after
#  캐리어를 안 잃어버리는 곳에 있어서 십분쯤 후에 들어오면 될 것 같다고 하자 캐리어는 계단에 두고 들어오라고 한다
#
# Target summary
#  캐리어는 계단에 두고 10분쯤 후에 다른 사람 모르게 들어오라고 이야기하고 있다
#
# Text #주거와 생활# 캐리어 안잃어버리는곳에있어 십분쯤후에 들어오면될듯 캐리어는 계단에 두고 우선 너만와봐 들어옴 안방방문닫혀이 지 내가 닫아놈 #@이름# 모르게 하려고 닫혀있음
# ----------------------------------------------------------------------------------------------------
#
# idx_6700
#
# Summary after
#  아침에 지나가면서 보니까 7시부터 마스크 판매라서 동네 약국에 줄을 섰다
#
# Target summary
#  7시부터 마스크를 판매한다는 동네 약국 앞에 사람들이 많이 몰려 줄을 서고 있다
#
# Text #주거와 생활# #@시스템#사진# 야 우리동네 약국 줄선거 봐봐 아 퇴근시간이라 몰렸네 아니 그게아니라 아침에 지나가면서 보니까 7시부터 마스크 판매한다고 돼있었는데 줄이 저래 요즘 버스타고 가야 지나가면 저 광경 맨날본다 아니 개금 마스크 대란이다
# ----------------------------------------------------------------------------------------------------
#
# idx_6800
#
# Summary after
#  저번에 산 풍선이 불량 같다며 사진을 보내자 오른쪽처럼 되어야 한다고 말한다
#
# Target summary
#  저번에 산 풍선이 불량이라서 하늘색 하나만 제대로 불어진다고 하니 더 불어서 공기를 위쪽으로 올리라고 한다
#
# Text #주거와 생활# 저번에 산 풍선 불량같아 왜 안불어져 #@시스템#사진# 오른쪽처럼 되야하눈데 저거 하늘색 하나만 제대로 불어지고 나머진 왼쪽처럼 저래 더 불어야돼 그리고 뒤쪽잡고 공기위로 올려 아아 터질것같아 무서워 그리고 내가 아까 살짝 공기가 뒤로가게 주물르니까 #@이름#도 도망가던데 안터지게 살살해야지
# ----------------------------------------------------------------------------------------------------
#
# idx_6900
#
# Summary after
#  아빠 눈 수술을 하러 가는데 차를 끌고 가서 대리 부르고 엄마한테 혼났겠다고 한다
#
# Target summary
#  아빠께서 눈 수술하러 가는데 차 가져갔다가 돌아올 때 대리를 불러서 왔다고 대화한다
#
# Text #주거와 생활# 웃긴얘기있어 머 아빠 눈수술하러 가는데 차끌고가서 대리부름 개웃겨 엄마한테 혼났겠네또 눈수술하러가는사람이 무슨 차를가져가냐고 대리비15000원 아빠 돈쓸데 없대 돈 길거리에 버리구싶대
# ----------------------------------------------------------------------------------------------------
#
# idx_7000
#
# Summary after
#  토요일에 12시에 끝나는데 홍대에 오면 46분이 걸린다
#
# Target summary
#  토요일에 12시에 끝나는 데 이동에 걸리는 시간에 대해서 이야기한다
#
# Text #주거와 생활# 마쟈 나 토요일에 아마 12시에 끝나는데 언제 만날려 너 홍대오면 몇신데 46분 걸린대 고람 1시 쳐자다가 지금 일어났다 하 #@이름# 서울집에서 오는겨 아님 천안에서 오는겨 서울집이즤 홍대 가깝지 내가 퇴근할때 알려줄게 그치 뭐 2 30분이면
# ----------------------------------------------------------------------------------------------------
#
# idx_7100
#
# Summary after
#  호텔 말고도 무료 와이파이가 있는지 찾아보려고 한다
#
# Target summary
#  숙소에 무료 와이파이라고 적혀 있는데 포켓 와이파이를 들고 다녀야 하지 않을까 한다
#
# Text #주거와 생활# 글쿤 호텔말고도 좀 찾아볼까 여기는 형 안에 머 와이파이랑 이런거 다잇더나 호텔에 와이파이없는데도있나 무료와이파이라 적혀있네 나 와이파이는 잘모르겟다 나 그거 들고댕겻다 포켓와이파이 아아 그거 해야하지않을까 우리 미아되면 어캄
# ----------------------------------------------------------------------------------------------------
#
# idx_7200
#
# Summary after
#  여섯 시에 마치면 사십분이면 비슷할 것 같다
#
# Target summary
#  위치가 애매하여 환승하기 싫어서 버스를 타고 한 번에 가려다 같이 6시 40분에 비슷하게 도착할 것 같다
#
# Text #주거와 생활# 여섯시마치고 바로옿거비 올거지 #@시스템#검색# 앙 오면 몇시야 나 여섯시 한 사십분 아 나듀 비슷하겠당 진짜 니가빠를거같앗는뎅 앙 위치가 애매해서 구냥 환승하기 시러서 버스타고 한방에 가게
# ----------------------------------------------------------------------------------------------------
#
# idx_7300
#
# Summary after
#  이제 겨울이니까 당연한 건데 내일도 오늘과 똑같이 엄청 춥다
#
# Target summary
#  겨울이라 추운 건 당연하지만 내일이 오늘과 같거나 더 춥다니 별로다
#
# Text #주거와 생활# 내일 날씨도 오늘이랑 똑같이 엄청 춥네 오늘이랑 똑같단 말이야 물론 이제 겨울이니까 당연한거지만서도 날씨가 추우니까 별로야 웅게다가 같거나 아님 오히려 더 추울 수도 있다니까 진짜 더 별로얌 그런데 이와는 별개로 너가 맨날 날씨를 봐주니까 좋다
# ----------------------------------------------------------------------------------------------------
#
# idx_7400
#
# Summary after
#  겨울이 되니까 밤에는 추워서 밥을 안 먹었더니 배가 고프다
#
# Target summary
#  밤에 춥다고 했더니 바보 같은 말이라고 이야기한다
#
# Text #주거와 생활# 어우밤엔 춥다 너 그거알아 바보같은 말 멀라 아우 밥 안먹엇더니 배고프다 어우 겨울되니까 춥다 어우 밤엔 춥다 어우 잠을 안잣더니 피공하다 머쓱
# ----------------------------------------------------------------------------------------------------
#
# idx_7500
#
# Summary after
#  택시가 오고 있는데 막혀서 5분이 걸린다
#
# Target summary
#  차가 막혀서 택시가 늦게 도착해서 지각할 위기에 놓였다
#
# Text #주거와 생활# 택시타쏘 아니 아직 늦겠다 아직두 헐큰일났네 택시가오고는있는데늦넹 전화왔는데 막히나봐5분정도걸린뎅 여보도집에서바로나가야겠당 나쟈철역와쏘 나이제타고출발 언넝뛰어가
# ----------------------------------------------------------------------------------------------------
#
# idx_7600
#
# Summary after
#  너랑 살 때는 담배 피우는 거나 일어나서 준비하는 거나 신경 안 써도 되지만 그래도 주말에 담배 피우러 간다
#
# Target summary
#  같이 사는 사람이 금요일에는 알바가 있어서 매주 집에 간다
#
# Text #주거와 생활# 진짜 너랑살때는 담배피는거니 일어나서 준비하는 거니 이런거 신경크게안써도돾는데 #@이모티콘# 그래도 주말에 집가서 천만 다행이다 그니까 금욜에 알바래서 매주간다고하더라고 다행이다 그래도 방에 잘 안 들어오나봐
# ----------------------------------------------------------------------------------------------------
#
# idx_7700
#
# Summary after
#  여보에게 파키 말고 다른 박치기 공룡 이름이 생각나냐고 물었더니 검색에 안 나온다고 한다
#
# Target summary
#  부부가 아이에게 사 줄 공룡에 대한 정보를 확인하고 있다
#
# Text #주거와 생활# 여봉 #@이름#이가얘기한 파키말고 다른 박치기공룡 이름생각나 스키몰루쿠 검색에안나와 스티키몰루크 지옥 악마 뭐 그런거였는데 스티키몰로크 찾았어 역시 기억력짱 머하게 사게 응 사줄라고 파키는 어쩌고 같이줘야지 이건디게쪼꼬매 그려
# ----------------------------------------------------------------------------------------------------
#
# idx_7800
#
# Summary after
#  긴급재난지원금 카드 혜택 그대로 된다고 하니 우리카드로 하면 네이버 페이 적립도 그대로 되는 건가 싶다
#
# Target summary
#  긴급재난지원금 카드 사용 시 기존 카드 혜택이 동일하게 적용되는지 확인한다
#
# Text #주거와 생활# 이거 긴급재난지원금 카드 혜택 그대로 된다고 한다이가 그럼 우리카드로 하면 네이버페이 적립도 그대로 되는건가 그렇지않으까 나도 그래서 우리카드로 하랴고 전화해서 언니랑 엄마랑아빠랑 다 내일이네 물어봐봐
# ----------------------------------------------------------------------------------------------------
#
# idx_7900
#
# Summary after
#  회사에 볼펜과 물티슈가 필요한데 모나미밖에 없다
#
# Target summary
#  회사에 필요한 볼펜과 물티슈 대신 청소포를 가져다 준다
#
# Text #주거와 생활# 또 회사에 모필요해 볼펜 가따두께 물티슈 볼펜은 모나미밖에업서 물티슈도 있어 청소포 가따줄까 어 줘 다줄게
# ----------------------------------------------------------------------------------------------------
#
# idx_8000
#
# Summary after
#  공항까지 버스를 검색하니까 한 시간 반 정도 걸린다
#
# Target summary
#  공항버스를 타고 공항까지 걸리는 시간에 대해 이야기한다
#
# Text #주거와 생활# 공항가는버스 5시반에는 타야겠다 나두 더 일찍 가야되는거 아니야 공항까지 얼마나걸려 버스검색하니까 한시간반정도걸리네 흠 더일찍타야하나 한시간반씩이나걸려 #@이름#이 비행기가 8시5분이니까 두시간 전부터 탑승수속할걸 난 7시50분뱅기야 껄껄 후 몇시에타야하지 4시 30분엔 타야할듯 난
# ----------------------------------------------------------------------------------------------------
#
# idx_8100
#
# Summary after
#  소소한 이삿짐들이 있는데 혹시 망가뜨릴까 봐 서랍에 짐을 싸려고 한다
#
# Target summary
#  소소한 이삿짐들을 망가뜨릴까 봐 직접 싸고 매일 쓰는 것만 꺼내 두었다고 한다
#
# Text #주거와 생활# 그래서 우리는 소소한 이삿짐들잇자나 응응 내방 서랍에 짐 이런건 혹시 망가뜨릴까봐 내가 싸느라고 너가 직접 박스에 다 포장해둠 힘들어 기짐 엉 박스옮기기만 하면되게 해두는군 내방은 거의 다했음 맨날 쓰는것만 꺼내둠
# ----------------------------------------------------------------------------------------------------
#
# idx_8200
#
# Summary after
#  원산구에 비가 너무 많이 와서 침수되는 것은 아닌지 걱정한다
#
# Target summary
#  비가 너무 많이 와서 침수될까 봐 걱정이다
#
# Text #주거와 생활# 비 엄청 오는건가 그런듯 침수되는건 아니겠지 그럴수도 이정도면 원산구 비 너무오는데 정말 그냥 다 폭우인거 같아 침수 피해없기를 바래야지 그래도 여긴 침수되고 그런건아니니깐 다행이지
# ----------------------------------------------------------------------------------------------------
#
# idx_8300
#
# Summary after
#  검색대에서 굽구뵤해서 탔는데 살짝 지연인 것 같다고 하자 버스라고 한다
#
# Target summary
#  지연이 돼서 버스 타고 가고 있다고 하자 슬슬 준비해서 나가겠다고 하고 있다
#
# Text #행사# #@시스템#사진# 검색대에서 굽구뵤해서 탐 휴 살짝 지연 인가바 짐 버스야 구걸 아 더워 다행이네 그럼 나도 슬 준비해야게꾼 오면 해물찜으로 몸보신해 웅 아오
# ----------------------------------------------------------------------------------------------------
#
# idx_8400
#
# Summary after
#  운동 끝나면 아홉시에 걸어서 오자고 한다
#
# Target summary
#  카페에 가면 더 늦어진다고 하니 운동을 10시 20분에 끝내서 같이 걸어오자고 한다
#
# Text #행사# 운동갈까말까 나운동끝나면아홉신데 가티걸어오쟈 아홉시 나 #@이름#이랑 카페가면 더 늦어질거같은뎅 그럼 10 20 덕분에 한시간 더 땡긴다 옼돜 넘힘드루
# ----------------------------------------------------------------------------------------------------
#
# idx_8500
#
# Summary after
#  웨딩촬영을 할 때 갈 수 있으면 좋겠고 평일 주말에 잡으려고 한다
#
# Target summary
#  웨딩촬영에 오고 싶어 해서 날짜가 잡히면 알려주기로 한다
#
# Text #행사# 좋구나 웨딩촬영은 그것도 이제 알아봐야지 촬영할 때 나도 갈 수 있으면 좋겠당 그래주면 고맙징 언제로 잡을꺼야 평일 주말 음 아무래도 평일오후일거 같아 아 안돼 날짜 잡히면 알려줄게
# ----------------------------------------------------------------------------------------------------
#
# idx_8600
#
# Summary after
#  어디든 상관없는데 종각이면 너무 많이 기다린 것 같다고 한다
#
# Target summary
#  종각이면 많이 기다릴 것 같지만 유튜브를 보면 되고 종로 가서 좀 누워있을까 싶다
#
# Text #행사# 어디든상고나옶어 나두 긍데 종각이면 자기 너무 마니 기다리눈고 가타 아니얌 나 유투브 보면대 난 고기도 좋고 오랜만에 신촌고 좋구우 종로가서 좀 누어잇으까 히 배달시켜머그까 안고 누워잇구 싶당
# ----------------------------------------------------------------------------------------------------
#
# idx_8700
#
# Summary after
#  전북 투어패스가 있는데 쓸지 이야기하고 임실이나 가볼지 이야기한다
#
# Target summary
#  전북 투어패스를 받아서 임실의 치즈마을에 갈지 고민하고 있다
#
# Text #행사# 나 전북투어패스 있는데 쓸래 그게 모하는거야 전북 돌아댕기는가여 #@url# 이건가봄 오 임실이나 가볼 치즈마을가
# ----------------------------------------------------------------------------------------------------
#
# idx_8800
#
# Summary after
#  보통 셀렉 하러 한 달 뒤쯤 가니까 될 것 같긴 한데 플래너한테 물어볼까 한다
#
# Target summary
#  플래너와 일정을 조정하기 위해 언제가 좋을지 얘기하고 있다
#
# Text #행사# 보통 셀렉하러 한달뒤쯤 가니까 될거같긴한뎅 물어볼까 플래너한테 근데좀빠듯해지지않아여 옹 그렇긴한데 물어나보지뭐 #@이름#아 봤지 9월초에해도된다는데 넌 어때 너가 편한대로 잡으삼 우짤까 #@이름# 근데 그냥 혹시모르니 안전하게 6월하는게 나을거같아여
# ----------------------------------------------------------------------------------------------------
#
# idx_8900
#
# Summary after
#  어디서 만날지 고민하다가 한전에서 보기로 했다
#
# Target summary
#  아이들 재우고 이제 나간다며 한전에서 보자고 한다
#
# Text #행사# #@이름# #@이름#이 자는거 같은뎅 엇 아니다 우디야암 이제나가 #@이름#만나러 어디서 만나 나도 이제 나왔듕 한전에서 볼까 #@이름#이랑 중파에서 만나기로햇엉 웅 나 걸어가고이쏘 웅웅
# ----------------------------------------------------------------------------------------------------
#
# idx_9000
#
# Summary after
#  여의도 아이에프씨 몰에서 만나 맛있는 것을 먹기로 했다
#
# Target summary
#  둘이 여의도 아이에프시몰에서 만나 맛있는 것을 먹기로 했다
#
# Text #행사# 맛난거 먹자 응 연락할겡 오키 나 가는 중 어딨어 여의도 ifc몰 오키 #@시스템#사진# 오 필터 써서 바꾸시오 응
# ----------------------------------------------------------------------------------------------------
#
# idx_9100
#
# Summary after
#  어디쯤 왔냐고 물으니 야탑에 와있다고 한다
#
# Target summary
#  식사 약속이 있어서 야탑에 왔다
#
# Text #행사# 어디쯤왓어 융 내렷어 난 옥 야탑 #@이름# 와있대 융 좋은시간보내 #@이름# 드러가잇대 웅 #@이름#두 잘쉬어에 밥 맛나게드시고용 넵
# ----------------------------------------------------------------------------------------------------
#
# idx_9200
#
# Summary after
#  저녁에 운동을 가려고 하는데 너무 더워서 떨어지면 안 된다고 한다
#
# Target summary
#  이따가 해가 떨어지면 같이 운동하러 가기로 했다
#
# Text #행사# 자기 저녁에 운동할꾸야 운동 갈깡 근데 해 떨어지구 가면 안될깡 넘더워더웡 #@이모티콘# 알겠어요옹 그럼 이따가 해 떨어지면 갑시당
# ----------------------------------------------------------------------------------------------------
#
# idx_9300
#
# Summary after
#  학생증을 주워서 주인을 오늘 만나기로 했는데 답장이 없어서 번거롭다
#
# Target summary
#  학생증 주워서 오늘 주인 만나기로 했는데 답장이 없다고 하니 학생처에 맡기고 맡겼다고 남기는 게 낫지 않겠냐고 말한다
#
# Text #행사# 내가 학생증 주워서 주인 오늘 만나기로 했는데 답장이 없어 오잉 번거롭겠다 학생처에 맡기고 맡겼다고 남기는게 낫지 않을까 바로 근처 학교야 그 학교가 용인대학교던데 기숙사랑 멀어서 페북 찾아서 연락했더니 월요일 저녁에 나 사는 기숙사쪽으로 오겠다고 그러더라구 근데 내가 오늘 화장품 가게를 먼저 들렸다 만나고 싶어서 연락했는데 안받아 찾아준 건 #@이름#인데 묘하게 일 번거롭게 만드네 그분#@이모티콘#근심##@이모티콘#근심# #@이름#는 계획했던일 하는 게 좋을 거 같아 연락도 먼저 남겼구 #@이모티콘#궁금# 그치 바쁘진 않은데 얼른 전해주고 아이스 아메리카노 사러 갈건데
# ----------------------------------------------------------------------------------------------------
#
# idx_9400
#
# Summary after
#  일요일에 홍대에 가서 윤시밀을 보기로 했다
#
# Target summary
#  추운데 홍대를 갈 거냐고 하니까 갈 곳 있으면 말해보라고 한다
#
# Text #행사# 일욜에본당 윤씨밀방 아니 추운데 홍대갈거야 구롬 구냥 물어보는던뎅 갈대익으면 말해바 알엇오
# ----------------------------------------------------------------------------------------------------
#
# idx_9500
#
# Summary after
#  9일 뒤에 여행을 간다고 해서 갔다 와서 보기로 했다
#
# Target summary
#  갑자기 만난 사람이 9일 뒤에 여행을 간다고 해서 갔다가 와서 보자고 했다는 얘기를 한다
#
# Text #행사# #@시스템#사진# 깩 #@이름# 나두 #@이름# 보고싶다 갑자기 만남 9일 뒤에 여행간데 그래서 갔다와서 보자했어 오오 잘쉬고오라해 8 8 #@이름#
# ----------------------------------------------------------------------------------------------------
#
# idx_9600
#
# Summary after
#  범일역에서 만나기로 하고 어디서 내릴지 이야기한다
#
# Target summary
#  웬일로 떼를 쓴 게 통해서 만나기로 했으며 상대를 만날 생각으로 벌써 양정에 와 있다
#
# Text #행사# #@이름# 어댜 만나실 오잉이 좋아 떼가통했군 범일이야 로키 오키 나 양정이여 어디서내릴까 시청 오키그럼양정에서내릴까 나 방금 니 만날생각으러 왜 양정이지 근데 앵정으로 왔셔 오 좋아 감덩이군
# ----------------------------------------------------------------------------------------------------
#
# idx_9700
#
# Summary after
#  상암동 언니네에 갈지 말지 고민 중이라고 하자 엄마를 보러 오면 된다고 한다
#
# Target summary
#  상암동에서 약속이 있으며 언니네 엄마를 보러 가기로 한다
#
# Text #행사# 어디서 약속 상암동 언니네 갈까 말까 고민중 어 엄마 보러 오면 되징 그러게 나도 가급적 일찍 들어갈테니까 그래 그럼 가서 자야겠당 알써 이따봐
# ----------------------------------------------------------------------------------------------------
#
# idx_9800
#
# Summary after
#  노량진에 수산시장이 있는데 컵밥이랑 학원 간다
#
# Target summary
#  노량진에 다음에 컵밥을 먹으러 가자고 말한다
#
# Text #행사# 노량진하면 뭐가 떠올라아 음 수산시장 오옹 맞다 수산시장듀 있지 나는 컵밥이랑 학원가 아 그렇구나 오래전에 노량진 지나가다 언니랑 컵밥 먹어봤던 거 기억나 웅웅 개존맛이었지 치즈 쭈유 아아알 늘어나고 다음에 기회가 되면 한번 또 가보자 넹넴
# ----------------------------------------------------------------------------------------------------
#
# idx_9900
#
# Summary after
#  화장실에 오느라 올라왔는데 위에서 기다릴지 믿음에서 기다릴지에 대해 이야기한다
#
# Target summary
#  화장실을 가야 해서 올라온 것을 이야기하며 마중 나갈 것에 대해서 이야기하고 있다
#
# Text #행사# #@이름#아나화장실오느라 올라왔엉 위에서 기다릴까 믿에서 기다릴까 도착했어 나도 곧내려 진짜 마중나갈까 아냐 어디야 버스 한정거장 남았어 지하철 안에 카드찍는데 앞에있어 알았웅앜
# ----------------------------------------------------------------------------------------------------
#
# idx_10000
#
# Summary after
#  내일 대전으로 오시길 바라지만 가면 올 때 우울할 것 같다
#
# Target summary
#  목요일 저녁에 동탄에서 보던가 금요일 오전에 데이트를 하자고 한다
#
# Text #행사# 혼자 노는거 재미써여 재미업써영 놀자아 대전으로오시길 갈까 내일 근데 가면 올때 넘 우울인디 금욜 오전에 안바쁘시면 데이트 어떠십니깡 힣 목욜 저녁때 동탄에서 봐도대궁 다 좋습니당
# ----------------------------------------------------------------------------------------------------
#
# idx_10100
#
# Summary after
#  디케이티 왕복 티켓값이 비싸졌지만 그래도 이 정도는 된다
#
# Target summary
#  왕복 푯값이 저렴한데 아일랜드가 섬이 맞는지 헷갈린다
#
# Text #행사# #@시스템#사진# 이게 왕복 티켓값이래 엥 왕복 왜케 싸 dkt #@시스템#사진# 2인으로 하니까 좀 더 비싸졌어 그래도 이정도묜 그래도 싸네 런던 더블린 스코틀랜드 런던 나 아직 월급 못받았는데 대충 일케하면 되지 않을까 기둘기 더블린 아일랜드도 갈거 난 가보고싶은뎅 사실 경로는 나도 잘 가면 좋긴한데 아일랜드가 섬 아닌가 그러면 런던 인 더블린 아웃 이런 식으로 가는게 나으니깐 그럴까 근데 아일랜드 섬 맞아 헷갈려 웅 옆에 떨어져있어 #@시스템#검색# 그럼 굳이 런던으로 돌아올 필요 없으니깐
# ----------------------------------------------------------------------------------------------------
#
# idx_10200
#
# Summary after
#  아직 아무도 못 일어나서 천천히 준비하라고 하자 언니가 우리 애들도 자고 있어서 안고 차에 태우겠다고 한다
#
# Target summary
#  식구들이 방금 일어나서 동생에게 준비를 다 했으면 먼저 출발하라고 이야기하고 있다
#
# Text #행사# 천천히 준비하삼 우리 아직 아무도 못일어남 미안 네네언니 저희애들도 자고 있어서 안고차에태우려구요 #@이름#아빠도 지금일어남 네넹 기다리구있을게용 아냐아냐 준비 다했음 슬슬 먼저가삼 괜히 기둘리면 미안해
# ----------------------------------------------------------------------------------------------------
#
# idx_10300
#
# Summary after
#  동래 가까운 영화관에서 8시 영화를 보려고 한다
#
# Target summary
#  다른 곳은 시간이 너무 늦어서 차를 타고 동래 온천장 역에 있는 씨지브이에 가서 밤 8시에 영화를 볼 것에 대해 이야기한다
#
# Text #행사# 니 밤에 잠안오면 우짤라고 영화밤에볼거야 8시꺼 어디서 보누 동래 가까운데 가네 웅 살랑살랑 걸어갔다가 올끼가 다른곳은 시간이 너무 늦더라 차타고갈꺼야 온천장역에 씨지비 갈거거둥 글쿠나 웅 재밋게 보고온누 알쏭
# ----------------------------------------------------------------------------------------------------
#
# idx_10400
#
# Summary after
#  설날인데 시골에 갔다가 왔는데 할머니 집 옆 동네라서 부럽다
#
# Target summary
#  설날인데 너무 멀어서 안 간다며 데이트하면 되겠다고 하자 이제 씻고 나간다고 한다
#
# Text #행사# 설날인데 시골갔어 갔다가 왔징 할머니집 옆동네라 너는 아 부럽다 난 지리산이랑 해남인데 멀어서 그냥 안갈려구 오늘 회사 당직이라해놨엌 너무멀다 안가고 광주에서 데이트하면되겠당 웅 안그래도 이제 씻고 나가려고
# ----------------------------------------------------------------------------------------------------
#
# idx_10500
#
# Summary after
#  내일 저녁을 같이 먹어도 되는지 물어보고 있다
#
# Target summary
#  지인과 같이 밥 먹으려 하는데 다음날 시험인데 밥 먹어도 괜찮기는 하겠다
#
# Text #행사# 내일 #@이름#하고 #@이름#랑 같이 저녇 녁 먹어도 되나염 녜에 그게 뭔소리야 표정왤케 심각해 #@이름#가 같이 저녁먹자는데 나 저녁먹고 학원가야햄 읭 저녁 어디 정해둔 곳 있으면 그담날 시험인데 같이 밥 먹자고 너희 만나서 먹엉 아 같이 먹어도 괜찮긴 하겠다
# ----------------------------------------------------------------------------------------------------
#
# idx_10600
#
# Summary after
#  8시까지 비가 올 수 있어서 오래 있어야겠다고 이야기한다
#
# Target summary
#  비올까봐 카페에 있으면서 선배와 저녁 같이 먹었다고 얘기하고 있다
#
# Text #행사# 헉 근데 이따가 비 올 수 도 있나봐 8시까지 헐 여기 오래있어야겼다 친구들이랑 얘기하면서 있엉 비내리는 날 카페에서 난 선배랑 밥 먹었엉 저녁 이제 집으로 갈려고 집 도착해서 톡할게 응응 조심히가 가족들이랑 저녁먹는다고했징 그럴까했는데 회사에서 오늘 야간근무하는 선배랑 먹었어 얘기할것도 있고 요새 같이 통 못 먹어성 집에선 간단하게 조금 늦게 먹을듯해
# ----------------------------------------------------------------------------------------------------
#
# idx_10700
#
# Summary after
#  내일 엄마가 일하러 가고 아빠도 시골에 가셔서 집에서 맛있는 거 시켜 먹고 노는 건 어떠냐고 한다
#
# Target summary
#  내일 저녁에 집에서 음식을 배달 시켜 먹고 놀기로 한다
#
# Text #행사# 얘들아 내일 엄마 저녁에 일하러가고 아빠도 시골간데 혹시 우리집에서 맛난거 시켜먹고 노는건 어떠니 미안 아빠가 이제서야 얘기해주네 좋지 그것두 나두괜춘 집에서보면 #@이름#도보구 더편하지 미안미안 #@이름# 있음 너네가 정신없을텐데 내가 낼 맛난거 시켜놓을게 너흰 몸만와 뭐먹고싶니 #@이름# 있으면 놀구 좋지 배달음식은다맛잇지 나퇴근후에바로가면되나 고마워
# ----------------------------------------------------------------------------------------------------
#
# idx_10800
#
# Summary after
#  마포대교를 같이 건너가서 만나기로 했다
#
# Target summary
#  서로 저녁으로 무엇을 먹을 건지에 대한 대화를 한다
#
# Text #행사# 아냐아냐 마포역에서 만날까 마포대교를 같이 건너가자 좋아 u200d 마포역까지 가는 버스 있으니까 딱 만나면 되겠당 저녁 뭐 먹기로 해써 일단 스벅에서 고민하기루 했엉 #@이름#이와 달리 우린 계획없이 살거든 #@이모티콘# #@이름#이와 스벅에서 해결하기루 했오 앗 스벅에서 샌듸치 같은거루 떼우는거야 #@이름#도 계획없이 살 때가 더 많다구 히히 나두 이제 밥 사러 가 오늘은 편의점 밥 먹어야지 u200d 오늘 하루두 너무너무 수고 많았어 친구랑 재밌게 놀구 이따 밤에 놀러가쟝 u200d
# ----------------------------------------------------------------------------------------------------
#
# idx_10900
#
# Summary after
#  오늘 꽁블에 갔는데 식사가 가능하고 메뉴가 바뀌어서 가고 싶었는데 메뉴가 그대로였다
#
# Target summary
#  꽁블에서 두부를 먹으러 갔는데 메뉴는 그대로지만 냉장고가 하나 더 생기고 소스를 판다고 말하고 있다
#
# Text #상거래(쇼핑)# 오늘 꽁블갓다 이제 식사가능 두부 맛잇더라 아 가고 싶엇는데 메뉴 많이 바뀜 뭐 생겼어 메뉴 그대로던데 그냥 냉장고하나 더생김 거기에 소스 팔아 아하 좋당 근데 개비싸지
# ----------------------------------------------------------------------------------------------------
#
# idx_11000
#
# Summary after
#  대형마트에서 대부분 저 브랜드 상품을 팔아서 가지 말자고 한다
#
# Target summary
#  대형마트에서 대부분 저 브랜드의 저질의 상품을 팔아서 갈 필요가 없고 가지 말아야겠고 인터넷에서 산다
#
# Text #상거래(쇼핑)# 아 저질의 상품을 팔다니 저긴 갈필요가없군 가지말자 대형마트에서 대부분 저 브랜드 팔아 에휴 그래서 난 인터넷에서 사
# ----------------------------------------------------------------------------------------------------
#
# idx_11100
#
# Summary after
#  교환을 위해 기업은행에 입금하고 상세 사유 입력란에 대해 이야기한다
#
# Target summary
#  상세 사유 입력 안에 뭐라고 쓰냐고 묻자 가운데 잠금 키 불량과 잠금 및 해제가 되지 않는다라고 쓰라는 이야기를 하고 있다
#
# Text #상거래(쇼핑)# 교환 33 000원 기업은행 입금할게요 그리고 옙 #@시스템#사진# 뭐라고 하지요 상세사유입력란에요 상세사유 가운데 잠금키 삽입부분 불량 잠금 및 해제가 되지 않음
# ----------------------------------------------------------------------------------------------------
#
# idx_11200
#
# Summary after
#  북마크와 캐럿 중 무엇을 살지 고민하고 있다
#
# Target summary
#  살 것을 북마크 해놓고 고민 중인데 바지 위주로 살 것이다
#
# Text #상거래(쇼핑)# 다 골랐음 머살거임 그쪽은 북마크해놈 근데 고민중 난 바지위주로 살거야 캐럿이좋냐 모 머시기가 좋냐 걍 똑같 둘다 똑같은거잇는것도 많아
# ----------------------------------------------------------------------------------------------------
#
# idx_11300
#
# Summary after
#  가터는 타오바오가 최고인데 너무 먼 대륙이라 더 뒤져봐야겠다고 한다
#
# Target summary
#  타오바오와 성인용품 사이트에서 가터벨트를 많이 판다
#
# Text #상거래(쇼핑)# 가터는 타오바오가짱인데 넘나 먼 대륙 그냥 더 뒤져봐야겠음 성인사이트 성인용품 그런데뒤져봐 앜 까하 별거다있어
# ----------------------------------------------------------------------------------------------------
#
# idx_11400
#
# Summary after
#  스파오가 한화 라커디움만 하겠냐고 하자 그럼 이랬는데 나중에 출시될 때 가격을 듣고 스파오를 주겠다고 한다
#
# Target summary
#  한화 라커 디움에서 출시한 옷이 너무 비싸니 스파오의 옷을 사자고 이야기한다
#
# Text #상거래(쇼핑)# 가격도 아무리 비싸도 스파오가 한화라커디움만 하겠어 그럼그럼 이랬는데 나중에 출시될때 가격듣고 스파오주제에 이러는거아니야 쉬익쉬익 이돈이면 라커디윰하지 이렇게 사람이 참 그래 스파오에서 나오는 한화티 다 쟁이자 라커디움 맨투맨 칠만원임
# ----------------------------------------------------------------------------------------------------
#
# idx_11500
#
# Summary after
#  어제 새벽에 너무 잠결에 핸드폰을 구매해서 오늘 아침에 취소한 것 같다
#
# Target summary
#  어제 새벽에 너무 급하게 핸드폰을 구매해서 오늘 아침에 취소했다
#
# Text #상거래(쇼핑)# 어제 새벽에 나도 너무 잠결에 후다닥 처리햇나봐 핸드폰구매 우웅 그래서 오늘 아침에 후다닥 취소한듯 깜놀해써 그런거같어 그럴수이찌
# ----------------------------------------------------------------------------------------------------
#
# idx_11600
#
# Summary after
#  친구 동생이 밈을 입는데 활용도가 좋아서 사려고 한다
#
# Target summary
#  두 개나 산 와이드 주름 바지를 추천한다
#
# Text #상거래(쇼핑)# 밈에드는가 삿다 #@이름#이도살랭 내친척동생이거입는데 활용도 지림 #@시스템#기타# 헐 이쁜데 구치 나 두개나 삼 헐 시크헤라 저기 직원복지 개조은 쇼핑몰 이거진짜안붙고 통풍오졐 헐구래 사줫다 나두살래 긴가 나두살래
# ----------------------------------------------------------------------------------------------------
#
# idx_11700
#
# Summary after
#  수원에서 찰스앤 키스 가방을 구경했는데 롯데몰이 아니었다
#
# Target summary
#  수원에서 애경백화점이 아닌 롯데몰에서 쇼핑을 했다
#
# Text #상거래(쇼핑)# 근데 우리 수원에서 가방 구경한거 찰스앤키스 애경 아니엇어 롯데몰이엇나 롯데몰을 갓엇나 우리가 우리 롯데몰로 간듯 넘어간듯 그리고 오다가 에이케이로 와서러브캣 구경하곸 아그랫낰 켁 #@이모티콘# 내기억력을 믿어뽜 맞을거야
# ----------------------------------------------------------------------------------------------------
#
# idx_11800
#
# Summary after
#  아까 산 게 결제가 안돼서 못 골랐는데 내가 해준다고 한다
#
# Target summary
#  쇼핑몰 결제가 되지 않자 다른 사람이 대신해줄 것을 부탁한다
#
# Text #상거래(쇼핑)# 나 아까 산 거 결제가 안 돼 아니 아직도 아니 결장이 아니러 못 골랐어 결제가 안 돼 내가 해줄게 아 싫어 아니 내가 해줄게 아니 그걸 왜 해줘 엉엉 아니 돈이 있데 안 되잖아 결제가 와 결제를 못하지 중국이라 그런가봐 돈 가져 가라고 싸발로멍 나 3초만애 결제 가능해 시러 아니 빨리 해야 받지 지금 당장 못 줘 돈 그럼 결제 해줄게 나중에 돈 줘
# ----------------------------------------------------------------------------------------------------
#
# idx_11900
#
# Summary after
#  5초도 안 돼서 매진이 된 것 같은데 왜 사는지 모르겠다
#
# Target summary
#  예매하기도 못 넘어갔는데 5초도 안 돼서 매진이 됐다
#
# Text #상거래(쇼핑)# 말이되냐 일분이뭐야 5초도 안돼서 매진된거같은데 #@시스템#사진# 이거 안했댘 나 왜 사냐 미린 야 근데 저거 해도 못할수준이야 맞아 나는 아예 예매하기에서 못 넘어감
# ----------------------------------------------------------------------------------------------------
#
# idx_12000
#
# Summary after
#  내가 산 슈펜 신발에 검정 스키니에 위에를 뭘 사야 잘 어울릴지 고민하고 있다
#
# Target summary
#  슈펜 신발과 검정 스키니에 어떤 옷이 어울릴지 이야기한다
#
# Text #상거래(쇼핑)# 내가산슈펜신발에 검정스키니에 위에를뭘사야잘어울릴까 그신발에블라우스가어울릴까 괜찮을가같은데 흰신발은 웬만하면 다 어울리잖 그렇치 잉
# ----------------------------------------------------------------------------------------------------
#
# idx_12100
#
# Summary after
#  저 맨 처음 보낸 티샤츠 두 개에 13만 8천 원이라 가격이 이해가 안 간다
#
# Target summary
#  이쁘지만 가격이 너무 비싼 티셔츠에 대해서 이야기한다
#
# Text #상거래(쇼핑)# 가격이 이해가 안 가 이쁘긴 한데 저 맨처음에 보낸 티샤츠 저거 두개에 13만 8천원이였어 어우 진짜 여유 있을 때 색깔별로 사고싶었는데 사야지 진짜 결제 직전까지 감 다음 달엔 꼭 질러 #@이름# 근데 진짜 내가 티셔츠 세개에 9만원에 삿는데 옷은 이쁘다 그니까 8월에 월급받으면 신발이랑 같이 사야지 나도 월급 받으면 신발이랑 옷 사야지 진짜 간만의 쇼핑일 듯
# ----------------------------------------------------------------------------------------------------
#
# idx_12200
#
# Summary after
#  마피아에 썼던 돈을 계산해 보려고 하는데 7만 원이 나왔다
#
# Target summary
#  마피아에서 썼던 돈을 계산해보니 둘 다 7만 원이라 돌았다고 한다
#
# Text #상거래(쇼핑)# 마피아에 썼던 돈 계산 해보려구 7만원 줘 팰까 나도 7만원 나옴 돌았네 꼐산하지 말골 돌았네 계싣하니까 화남 과금유도 돌았네 왜 샀냐
# ----------------------------------------------------------------------------------------------------
#
# idx_12300
#
# Summary after
#  아기 침대를 보고 있는데 예쁜 건 다 비싸고 아기 침대는 거의 가족 침대이다
#
# Target summary
#  슬슬 아기 용품들을 찾아보는데 가격이 전부 비싸다
#
# Text #상거래(쇼핑)# 아기침대보고잇는데 이쁜건 다비싸네 #@시스템#사진# 벌써 아기침대를 바여 언니 진짜 빠름빠름 근데 거의 가족침대사서 재우게 되지 않을까여 옹 나는 그냥 따로재우고싶어서 침대쓰다가 범퍼침대 이런걸로 갈아타려구 같이 못잘듯 몸부림심해서 이제 슬 아기용품 관심갖고이뜸 가끔씩 용품 비싸게 하려면 한도끝도없는거같아여 유모차도 옷도 넘비싸구 그르게잉 유모차 비싼건 너두아넹 300 200 이래하드랏 적당한게최고인듯
# ----------------------------------------------------------------------------------------------------
#
# idx_12400
#
# Summary after
#  66은 쿨그레이이고 34 1은 블로그 색이 이쁘다
#
# Target summary
#  천 소파라서 때는 탈 것이라고 하며 베이지가 없어서 쿨 그레이와 웜 그레이 중에서 어느 색이 나은지 이야기한다
#
# Text #상거래(쇼핑)# #@url# #@시스템#기타# 색이고민이네 34 1이 낫나 블로그색깔이뻐 저건 66인데 66은 쿨그레이 34 1은 웜그레이 웜그레이는 살짝 베이지가 섞인 느낌이랴 베이직중에골라 둘다 그레이여 베이지가 없단게 34 1로 해야게따 밝은색햐고 소파색 한달만지나도 신겻도안쓰일덧 근데 천 때는 안탄대 타것지 밝은색은 머리아프네
# ----------------------------------------------------------------------------------------------------
#
# idx_12500
#
# Summary after
#  오늘 현대백화점에서 기다린다고 하고 득템하자고 한다
#
# Target summary
#  피곤하지만 오늘 현대백화점에서 옷 구경하면서 기다린다고 한다
#
# Text #상거래(쇼핑)# 이따봐 현백에서 기다릴게 오잉 오늘 현백가는거여또 뀨 마쟈뀽 득템하자뀨 나 너무 피곤해 안된다 먼저가서 옷 구경하고닛어 난 옷구경 하고시픈거없어 알았어
# ----------------------------------------------------------------------------------------------------
#
# idx_12600
#
# Summary after
#  아침에 가려고 하는데 피곤해할 것 같기도 하고 지속도 괜찮은지 물어본다
#
# Target summary
#  향수를 1인 1개씩 주기 때문에 친구 것을 대신 받아다 주지 못한다
#
# Text #상거래(쇼핑)# 근데 거기꺼 좋아 지속도 쏘쏘 #@이름# 꼬드겨 봐야겠다 아침에 갈라는데 오호 써보고 싶노 피곤해할거같기도하고 아님 혼자라도 갈까생각중 내 것도 받아줘 1인 1개 흐그후스흐 흐긋 륵 안돼 내 향수 아 근데 천명인데 나도 향수 사고싶다 안될랑가 천 명이면 괜챦알거같기도하고 흠 애매하넹
# ----------------------------------------------------------------------------------------------------
#
# idx_12700
#
# Summary after
#  지인 소개로 헬스를 등록했는데 깎아주지 않는다
#
# Target summary
#  헬스를 3개월 165000원에 등록했는데 지인 소개로 왔다고 했는데도 안 깎아 주었다
#
# Text #상거래(쇼핑)# 헬스 등록했어 3개월 165000 부들부들 지인소개로왓다하지 그러세요 하돈데 근데안깎아주냥 4가지 긍게 등록해썰
# ----------------------------------------------------------------------------------------------------
#
# idx_12800
#
# Summary after
#  내일은 안 비쌀 것 같다고 하자 병원 간 김에 하나 사라고 한다
#
# Target summary
#  아끼려고 한 겹만 해서 비싸지 않다고 말하고 있다
#
# Text #상거래(쇼핑)# 한겹만햇옼 애껴야대 왱 안 비뺘 내일도하꼬야 내가내일 안 비쨔 병원간김에 하나사올겡
# ----------------------------------------------------------------------------------------------------
#
# idx_12900
#
# Summary after
#  당근 마켓에 하면 팔리지 않으니 팔고 수수료 반주면 안 팔고 안 팔려고 한다
#
# Target summary
#  당근 마켓에 팔면 팔리냐고 하니 내가 팔아줄 테니 수수료 50 달라고 하고 안 팔고 만다고 한다
#
# Text #상거래(쇼핑)# 근데 이거 당근마켓에 하면 팔리남 절대 안삼 내가 팔아줄까 수수료 50 아니 미친 저거 팔고 수수료 반주면 안팔고 말지 양심리쓰네 그럼 팔지말던가
# ----------------------------------------------------------------------------------------------------
#
# idx_13000
#
# Summary after
#  경품 이벤트 응모를 했는데 1등은 노트북이고 2등이 노스페이스이다
#
# Target summary
#  경품 이벤트로 1등은 노트북 2등은 노스페이스 패딩이 준비되어 있다
#
# Text #상거래(쇼핑)# 경품 이벤트 응모도 했오 엥 경품 이벤트는 뭐야 당첨되면 뭐주는데 그거 1등 경품이 노트북이고 2등이 노스페이스 패딩인가 소소한 기대 품고있다 헐 노트북 그림의떡이네 크게주네 팔백집 더맘에들어
# ----------------------------------------------------------------------------------------------------
#
# idx_13100
#
# Summary after
#  바로 샀어야 했는데 여기서도 다 팔려서 재입고 문의하라고 한다
#
# Target summary
#  다 팔려서 재입고를 문의하려 하고 오프라인 스토어는 남았는가 싶다
#
# Text #상거래(쇼핑)# #@시스템#사진# 망했긔 #@기타# 바로 삿어야햇다 #@시스템#사진# 여기서도 다 팔렸네 #@기타# 미틴 문의해 재입고 아 오프라인 스토어에서는 남았나
# ----------------------------------------------------------------------------------------------------
#
# idx_13200
#
# Summary after
#  애들 옷도 오늘 올 것 같은데 관세를 안 냈다
#
# Target summary
#  아이들 옷을 관세 없이 주문했다
#
# Text #상거래(쇼핑)# 근데 그뭐냐 애들옷도오늘올걸 헐 이미주문햇다고 했어 혹시 그거 관세 냈어 아니 안냈어 관세 안나올걸
# ----------------------------------------------------------------------------------------------------
#
# idx_13300
#
# Summary after
#  어버이날이 시즌이라서 꽃이 더 싸다
#
# Target summary
#  오늘은 꽃이 어버이날 보다 더 싼 것 같다
#
# Text #상거래(쇼핑)# #@시스템#사진# 예쁘지않니 꽃 근데 우리 어버이날에도 싸다싸다 맛 이랬자나 오늘은 더 싼거 같음 그때가 시즌이라 오히려 좀 비싼편이았나봐 꼬꽃종류3개나돵 이쁘다 #@시스템#사진# 이번것도 예쁘징 엉 세종류 했움 근데 한단 칠처넌 그때보다 싸서 토욜이라 내일 여기 문닫고 이러니 오늘 더 싼가 했는데 그런건 아니라대 누그끈디 가성비내려온다 맞제 가성비 지림
# ----------------------------------------------------------------------------------------------------
#
# idx_13400
#
# Summary after
#  집 앞에 있는 큰 마트에 가기로 했다
#
# Target summary
#  마트에 가자길래 큰 마트에 가는 거냐고 묻자 집 앞에 있는 큰 마트라고 대답한다
#
# Text #상거래(쇼핑)# 마트가자 그래 웅 마트 그 큰마트 가는거니 요올 넹 그 큰마트 집앞에 있는 큰마트에 갑니다
# ...
# ----------------------------------------------------------------------------------------------------
#
# idx_30400
#
# Summary after
#  실버 푸드를 키우고 싶은데 배변 훈련을 해줄 수가 없다
#
# Target summary
#  실버 푸들을 키우고 싶은데 배변 훈련을 해줄 수 없어서 고민 중이다
#
# Text #개인 및 관계# #@url# 넘나귀엽당 사랑스럽다 실버푸들 키우고싶은데 가장큰문제가 내가 배변훈련을 해줄수가없넹 엄마랑 얘기해봐요 힝 나도 자주 보여주공 키우게되면 자주보여주징 근데 모르겠당 스타필드 데려갈수도있고 그냥 문득 키우고싶은 요즈음 그치 키우고싶은데 빡쌔긴하당
# ----------------------------------------------------------------------------------------------------
#
# idx_30500
#
# Summary after
#  이미 다 저질러놨는데 기간을 늦추라고 설득을 당해서 말을 못했다
#
# Target summary
#  결국 말을 못 하고 설득 당했다고 기간을 늦춘다
#
# Text #개인 및 관계# 하 결국 말을못햇어 말을 했는데 설득을당했어 헐 왜 좀만더생각하래 이미 다 저질러놨는데 기간을늦추래 생각 핑요없어요
# ----------------------------------------------------------------------------------------------------
#
# idx_30600
#
# Summary after
#  돈가스와 카레를 먹어서 배가 부르다
#
# Target summary
#  돈가스 카레를 먹고 배가 부르다고 하고 있다
#
# Text #개인 및 관계# #@이름#밥이라능 #@시스템#사진# 앜 돈까스 카레당 배부르 #@이름#도 뭐 먹어야지 전 먹구 이떠 전 맨날 전먹으 안질려 갠추네
# ----------------------------------------------------------------------------------------------------
#
# idx_30700
#
# Summary after
#  사진에 있는 표정과 너무 귀엽다며 사진을 보여주자 귀엽다고 말한다
#
# Target summary
#  애완동물이 아기가 간식을 위해서 뭘 줄지 몰라도 일단 재롱을 떨고 본다
#
# Text #개인 및 관계# #@시스템#사진# 사진 뭐야 너무 귀엽 이거무슨줄이에여 표정이랑 넘 귀엽자너 저도멀라여 #@시스템#사진# 결국섰어 뭐는일단 서고보는겨 뭘줄지 모르는겨 혹시몰러 땅콩하나줄지 넘 귀엽지
# ----------------------------------------------------------------------------------------------------
#
# idx_30800
#
# Summary after
#  숟가락이 없어서 언니 번호를 물어보았더니 상자에 있다고 한다
#
# Target summary
#  숟가락이 뒤에 가면 상자에 있다고 한다
#
# Text #개인 및 관계# 언니 #@이름# 언니 번호 알아 #@시스템#기타# 감쟈 왱 숟가락이 없넹 그거 뒤에 가면잇어 상자에 오 대박 감사 꺅 찾았다
# ----------------------------------------------------------------------------------------------------
#
# idx_30900
#
# Summary after
#  아무리 생각해도 자신이 최고라고 하자 역시 자기애가 넘친다고 한다
#
# Target summary
#  자기 자신이 최고라며 자기애가 넘쳐서 세련된 사람이며 이 시대의 보석 이러고 해주었더니 마인드가 건강하다고 했다
#
# Text #개인 및 관계# 아무리생각해도 내가최고다 아앀갑자기요 역시 자기애 넘쳐 맞지 너처럼 세련된사람 흔치않다 캬캬캬캬 나는 마인드가 건강해 맞아요 이시대의 보석
# ----------------------------------------------------------------------------------------------------
#
# idx_31000
#
# Summary after
#  국가시험을 보는데 인성을 논할 때는 아닌 것 같다
#
# Target summary
#  국가시험 보는 사람에게 시험 망하라고 얘기했던 사람이 면접 볼 때도 욕해준다고 한다
#
# Text #개인 및 관계# 인성 구린놈아 너가 나한테 인성을 논할땐 아닌듯 난 나 국가시험 보는데 니가 나한테 시험 망해라 라고 말한거 아직도 생생하게 기억남 첨들어봄 그런소리 아 내가 그랬어 와 진짜 나느 과거에도 정말 열심히 최선을 다하며 살았구나 진짜 맘에 든다 너 이제 면접 볼 시즌 되면 그때도 취업 버전으로 욕해줌 가만안둔다 그땐 가만안두면 어쩔껀뎁 나랑 같이 재수하자 넌 시험 재수 난 변시재수
# ----------------------------------------------------------------------------------------------------
#
# idx_31100
#
# Summary after
#  오늘도 스트레스를 많이 받지 말고 스트레스 받을 때마다 볼 것이다
#
# Target summary
#  오빠와 동생이 서로 스트레스받지 말고 이번 주도 힘내자고 응원한다
#
# Text #개인 및 관계# 응응 나도 스트레스받을때마다 볼거야 응응 오늘도 스트레스 많이 받지말구 응응 오빠도 #@이름#이 난리쳐도 한귀로 흘려버랴 응응 이번주도 힘내 #@이모티콘# 우리 둘다 이번주 힘내자 응응
# ----------------------------------------------------------------------------------------------------
#
# idx_31200
#
# Summary after
#  이메일에 이름이랑 학번은 적어 보내야 할 것 같은데 왜 대답을 안 해주냐고 한다
#
# Target summary
#  이메일에 이름과 학번은 적어 보내야 할 거 아니냐고 하자 그렇다면서 왜 대답을 안 해 주냐고 한다
#
# Text #개인 및 관계# #@이름# 무슨#@이름#죠 몰랔 아니 이메일에 이름이랑 학번은 적어보내야할거아녀 그치 왜 대답을 안해줘
# ----------------------------------------------------------------------------------------------------
#
# idx_31300
#
# Summary after
#  오늘 저녁에 햄버거랑 떡볶이 중에 햄버거를 먹기로 했다
#
# Target summary
#  동생이 저녁으로 햄버거와 떡볶이 중에 무엇을 먹을지 고민하자 햄버거를 골라주었고 언니는 피자와 스파게티를 먹는다
#
# Text #식음료# 나오는 오늘 저녁 뭐 먹지 후보말해봐 햄버거랑 떡볶이중에 골라봐 후보가 넘 센데 햄버거 고고 언닌 머먹어 피자랑 스파게티 피자먹구싶당
# ----------------------------------------------------------------------------------------------------
#
# idx_31400
#
# Summary after
#  어차피 재난지원금으로 먹는데 너무 비싸서 혼자 먹는다고 한다
#
# Target summary
#  혼자 먹는데 너무 비싸다고 하자 어차피 재난지원금으로 먹는다고 하고 토요일 아침에 먹어야 한다고 한다
#
# Text #식음료# 넘비싸 혼자먹눙데 어차피 재난지원금으로 먹쟈너 이마넌 넘어 그러면 나 돼지 아니거든 사도 다 못먹거든 토욜 아침에 머거야지 그 무슨 나약한소리야
# ----------------------------------------------------------------------------------------------------
#
# idx_31500
#
# Summary after
#  갑자기 스테이크가 떠올라서 얼마 전에 스테이크를 먹었다
#
# Target summary
#  얼마 전 스테이크 굽는 영상을 보고 나서 스테이크가 먹고 싶다
#
# Text #식음료# 야 근데 갑자기 스테이크 꼴리네 스테이크 당신 부루주아 아니 그건 아닌데 스테이크가 갑자기 스테이키 얼마전에 스테이크 굽는 영상 봄
# ----------------------------------------------------------------------------------------------------
#
# idx_31600
#
# Summary after
#  우리 동네에 기가 막힌 케이크가 있는데 혹시 키리쉬 케이크 아니냐고 하자 초코덕후라면 알아야 한다고 한다
#
# Target summary
#  동네에 키리쉬케이크라고 있는데 초콜릿에 깊이 빠진 사람이라면 알아야 한다고 이야기한다
#
# Text #식음료# 우리동네 기가막힌 케이크 있는데 혹시 키리쉬케이크아니 초코덕후라면 알아야하는데 아니 뭔디 아 모르냐 그동안 뭐먹고 살았냐 #@시스템#검색# 저거 떡 케이크인디 저거 아니 뭐여 아녀 단면을 봐
# ----------------------------------------------------------------------------------------------------
#
# idx_31700
#
# Summary after
#  오늘 두 번 약속이 있어서 맥주 한잔하고 지금 가는 중인데 몸이 무겁다
#
# Target summary
#  역전 할머니 맥주에서 떡볶이와 짜파게티와 맥주를 먹었다
#
# Text #식음료# 아 난 오늘두 약속잇어서 맥주 한잔 하고 지금 가는중 몸이 무겁구나 칭구야 안주모옇나 #@시스템#사진# 떡볶쓰 자파게리 와 맛있겟노 역전할맥맞제 정답
# ----------------------------------------------------------------------------------------------------
#
# idx_31800
#
# Summary after
#  중국 당면을 사서 닭볶음탕을 불리는 시간이 중평보다 빠르다고 한다
#
# Target summary
#  중평 떡볶이 5번 먹을 값으로 중국 당면 사서 중평 떡볶이에 넣어먹고 싶지만 불리는 시간이 너무 오래 걸린다고 한다
#
# Text #식음료# 그리고 과연 중평보다 맛있겠냐고 노노 아닐텐데 중국당면사서 닭도리탕 불리는 시간이 아흑 넘 배고프구만
# ----------------------------------------------------------------------------------------------------
#
# idx_31900
#
# Summary after
#  배가 고프지만 한라봉은 다 물이라서 저녁에 새송이버섯 하나만 먹을 것이다
#
# Target summary
#  저녁은 한라봉 하나를 오래 갈아서 먹고 마음이 바뀌어서 새송이버섯 하나를 구워 먹는다
#
# Text #식음료# 저녁은 한라봉만 하나 물게 오래 갈엇넹 배고프자나 그거 다 물이라서 미안 마음 바껴서 새송이버섯 하나 구워먹는다 그래 그런거라두 좀 머거
# ----------------------------------------------------------------------------------------------------
#
# idx_32000
#
# Summary after
#  오늘 돈코츠 라멘이 너무 맛이 없어서 샌드위치밖에 먹지 않았다
#
# Target summary
#  오늘 음식을 조금밖에 안 먹어서 배가 고프다고 서로에게 말하고 있다
#
# Text #식음료# 나 배가 너무 고프다 나도 샌드위치밖에 안먹엇어 오늘 돈코츠라멘이 너무맛없엇어 후 나도 라면3입이링 요거트하나끝 다 버렷어 바렷어
# ----------------------------------------------------------------------------------------------------
#
# idx_32100
#
# Summary after
#  반찬 같은 참치 요리를 하고 있다고 하자 상대방이 무슨 요리를 하냐며 궁금해한다
#
# Target summary
#  참치로 반찬을 만들어서 먹어보고 실패하면 버린다고 해서 아깝게 왜 버리냐고 이야기한다
#
# Text #식음료# 나 요리 하고이떠 #@이름#이먹여주꺼야 요 리 무슨요리 으응 그냥 엄청간단한거 반찬같은거 참치 잘했어 맛있게먹을게 내가먼저먹어복 버릴거야 실패하면 왜버려 아깝게
# ----------------------------------------------------------------------------------------------------
#
# idx_32200
#
# Summary after
#  지금 배달 가능한 게 뭐가 있냐고 하자 치킨 없을 것 같다며 떡볶이를 시키려고 찾아보라고 한다
#
# Target summary
#  지금 배달 가능한 것은 없을 것 같은데 찾아보라고 한다
#
# Text #식음료# 그럼 지금 배달 가능한게 뭐가있을까 치킨 없을 것 같은데 왜 #@이름#땜에 없을 것 같은데 떡볶이 시키게 걸작 찾아봐
# ----------------------------------------------------------------------------------------------------
#
# idx_32300
#
# Summary after
#  저녁 6시에 만나기로 했는데 딱히 먹고 싶은 게 있냐고 물어본다
#
# Target summary
#  저녁 6시에 만나기로 하고 저녁에 뭐 먹을지에 대해 이야기한다
#
# Text #식음료# 그럼 저녁 몇시 쯤 만날가 여섯시 오키오카 #@이름#아 뭐 먹고싶운거 있나 잇니 음 딱히 생각나는건없어 저녁 나도 딱히 저녁으로는 생각나는게 없는데 디저트가 생각나 뭐먹을래 저녁 디저트
# ----------------------------------------------------------------------------------------------------
#
# idx_32400
#
# Summary after
#  마라탕이 멀어서 서브웨이를 먹기로 했다
#
# Target summary
#  마라탕 집이 멀어서 서브웨이 먹고 가겠다고 했는데 커피 빈에 이면 마라탕을 먹고 가도 안 늦었다고 한다
#
# Text #식음료# #@이름# 근데 그 긍방에 마라탕이 멀어 은근 여섯시 칼퇴야 걍 너들끼리 먹어 그럼 나 서브웨이 먹구 갈게 왜 갑자기 종로5가 카페야 그 근처기도하고 이뿌길래 카페가 또륵 커피빈이면 마라탕 먹고 가도 안 늦는데
# ----------------------------------------------------------------------------------------------------
#
# idx_32500
#
# Summary after
#  에그 드롭을 은행에서 보고 집에 들어가는 길에 포장 중인데 처음 먹어보는데 설렌다
#
# Target summary
#  은행 일을 보고 에그드랍에 가서 포장 중이다
#
# Text #식음료# 그리고 우리 에그드랍 겨서 은행일보고 집들어가는길에 포장중 처음 머거본다 설레 굿굿 매번 먹자고해노코 주문 밖에 기계로 못머겄는데 하래서 갓는데 기계로한다 현금결제가 없는거야
# ----------------------------------------------------------------------------------------------------
#
# idx_32600
#
# Summary after
#  도시락을 먹어봤는데 너무 먹고 싶어서 도로아미타불을 먹었다
#
# Target summary
#  너무 먹고 싶다고 하자 다이어트 도시락만 먹으면 오래 못 가고 치팅 데이가 있어야 한다고 한다
#
# Text #식음료# 친구냐 저건 너무 먹고 싶었대 친구야 모찌롤먹음 도로아미타불 양해점 내가 다욧 도시락 먹어봤는데 오래는 못가 중간에 치팅데이있어야해 그나마 나랑 토일은 치팅데이함
# ----------------------------------------------------------------------------------------------------
#
# idx_32700
#
# Summary after
#  저녁으로 고기를 먹는다고 하자 이건 무슨 고기냐며 매일 고기 먹는다고 한다
#
# Target summary
#  매일 고기를 먹는데 오늘 저녁의 고기는 달콤하면서도 쫄깃한 느낌의 고기여서 사르르 녹는다
#
# Text #식음료# #@이름#는 저녁 뭐먹냐리 고기 먹으뀨야 #@시스템#사진# 앜 이건 무슨 고기냐리 #@이름# 매일 고기 먹는다리 무슨 달꼼하면서도 쫄깃한 누낌의 고기얍 샤르르녹아 #@이름# 먹방 bj이야 표현력 보소
# ----------------------------------------------------------------------------------------------------
#
# idx_32800
#
# Summary after
#  집에 와서 치킨까지 먹었다고 하자 자기는 허니콤보를 먹었다고 한다
#
# Target summary
#  너 자는 사이에 난 집에 와서 허니콤보 치킨까지 먹었다
#
# Text #식음료# 이미집와서 치킨까지머것지잉 나 자는 사이에 많은걸햇넹 무슨 치킹먹엇어 웅 나 허니콤보 허니멜로먹을랫는데 교촌인줄알고 그거말햇는데 굽네꺼엿어 사장님 당황스
# ----------------------------------------------------------------------------------------------------
#
# idx_32900
#
# Summary after
#  맘스터치에 가면 문제집 피우고 서로 문제 내면서 버거가 당긴다
#
# Target summary
#  맘스터치에 가면 애들이 문제집을 펴서 서로 문제를 내면서 햄버거를 기다린다
#
# Text #식음료# 맘터땡긴다 그리고 여기 맘터가면 얘들이 오늘점심 마터머거야지 문제집피고 서로 문제내면서 버거 기다려 으악 맘터 존맛탱이겟다
# ----------------------------------------------------------------------------------------------------
#
# idx_33000
#
# Summary after
#  서울에서 먹고 싶은 게 있냐고 하자 고르곤졸라를 사 가겠다고 한다
#
# Target summary
#  서울에서 고르곤졸라를 사다 달라고 하고 있다
#
# Text #식음료# 아니 뭐 좀 사갈까 서울에서 먹고싶은거 있어 고르곤졸라 아니 그건 서울아니어도 되자나 그럼 서울에 머잇는지 몰라 보다 생각나면 말해 인스타 같은데서 고르곤졸라면 됨 몇일전에 먹엇는데 또 먹고싶가 되게좋아하네 서울오면 내가 맛난 곳으로 모시죠 서울언제 갈줄알고
# ----------------------------------------------------------------------------------------------------
#
# idx_33100
#
# Summary after
#  장지에 있는 프리미엄 애슐리 같고 맛있을 것 같다
#
# Target summary
#  여기 장지에 있는 프리미엄 애슐리인데 딸기 디저트가 엄청 많아 맛있어 보였다
#
# Text #식음료# 아 요기 그럼 거기랑 다른덴가부다 여기 장지에 잇는거같은 프리미엄애슐리넹 그런가바 오옹 마싯겟다 딸기디저트가 엄청만은데 맛잇어보이더라고 갠찬치않니 오얘 올겨울 못머근 딸기 다머거야징
# ----------------------------------------------------------------------------------------------------
#
# idx_33200
#
# Summary after
#  해장으로 도미노 피자와 포테이토 피자를 추천한다
#
# Target summary
#  해장을 도미노 포테이토 피자로 하라고 추천했지만 해장은 결국 라면이다
#
# Text #식음료# 해장이필요해 해장은 역시 도미노 포테이토피자 #@이모티콘# 피자 나피자진짜좋아해 피자나라피자#@이름# 결국은 라면이쥬 역시
# ----------------------------------------------------------------------------------------------------
#
# idx_33300
#
# Summary after
#  시나몬은 향만 강하면 먹고 다크 초콜릿은 향이 강하지 않으면 먹는다
#
# Target summary
#  시나몬이랑 다크초콜릿을 먹냐고 하자 시나몬은 향만 안 강하면 먹고 다크초코도 먹는다고 하자 참고하겠다고 한다
#
# Text #식음료# 언니 시나몬이랑 다크 초콜렛 먹어요 시나몬은 향만안강하면 먹어요 아 그래여 다크초코는요 먹어요 참고할게용 참고안하샤도되는데 주시는거면 팥도먹죠 팥은 아예 안먹는거에요
# ----------------------------------------------------------------------------------------------------
#
# idx_33400
#
# Summary after
#  편의점에서 쥐포를 사 왔는데 불에 구워 먹으면 맛있다
#
# Target summary
#  한 사람은 편의점에서 쥐포를 사 왔고 다른 사람은 할머니표 비빔국수를 먹기 위해 엄마와 이마트에서 장을 보는 중이다
#
# Text #식음료# 나는 편의점에서 쥐포 사왔어오 우왕 마싯겟다 쥐포 불에 구워먹으면 존마탱 으흐흐흐 #@시스템#사진# 장조림 만드는즁 오 대박 #@이름#가 나는 할머니표 비빔국수 머그꺼야 엄마랑 이마트에서 장보는중
# ----------------------------------------------------------------------------------------------------
#
# idx_33500
#
# Summary after
#  주꾸미가 먹고 싶어서 시켜 먹으러 가려고 한다
#
# Target summary
#  먹고 싶은 주꾸미를 이따가 시켜 먹기로 했다
#
# Text #식음료# 쭈꾸미 막고싶오 쥭겟다 어디야 좀아려주 바 시켜먹게 거기 늦게열어 잠만 아니다일 직연다 #@시스템#사진# 조아 이따 시켜주라 내 폰결제로 그려 이따 말하슈 언니 입에 안맞으면 어케 너가 맛잇는데 내가 안맛잇겟니 그치
# ----------------------------------------------------------------------------------------------------
#
# idx_33600
#
# Summary after
#  한국인들 끼니에 집착하는 게 웃기다
#
# Target summary
#  한국인은 매끼에 진심이라 끼니 늦으면 정색하고 모든 비유에 밥이 있다
#
# Text #식음료# 근데 한국인들 웃긴게 애 끼니에 다들 진심임 우리만 맨날 밥먹었냐고 집착해 역시 밥의 민족이야 좀 끼니 늦으면 왜 안먹었냐고 정색함 그리고 채팅하지 말고 밥먹으러 가라고 보낼라햌 역시 먹보의 민족 아까도 애 밥 안먹었다니까 다들 개정색하면서 왜안먹었냐고 계속 집착 아이참 잘먹고잘살려고하는건데 심지어 이말에도 먹고가 살고 앞에 있음 그니까 모든 비유에 먹는게 들어있음
# ----------------------------------------------------------------------------------------------------
#
# idx_33700
#
# Summary after
#  손을 씻고 요구르트 한 잔을 때렸는데 너무 독해서 취할 것 같다
#
# Target summary
#  손을 씻고 요구르트 한 잔을 마셨는데 달달하니 맛있다
#
# Text #식음료# 난 손씻구요쿠르트 한잔때렷다 워워 적당히마셔 취할라 너무 독하다 머가또독해 달달한게 맛잇겠지 맛있긴하지 취한다취해 키야
# ----------------------------------------------------------------------------------------------------
#
# idx_33800
#
# Summary after
#  소주병으로 만두피를 밀었는데 속이 통통해 보인다
#
# Target summary
#  소주 병으로 만두피를 밀어서 만두를 만들었다는 것과 옆집이었으면 갖다 줬을 것이라는 것에 대해 이야기한다
#
# Text #식음료# 나만두만듬 방금 만두피 밀엇다 소주병으로 와만두 마싯겠다 속 통통해보여 만두피 미는거 나도하고싶다 #@이름# 옆집이였으면 같은 아파트면 가져다줫을듯 최고다 그러면 순간이동 왜안돼
# ----------------------------------------------------------------------------------------------------
#
# idx_33900
#
# Summary after
#  아빠도 좀 먹게 족발을 시켰는데 부드럽고 맛있다
#
# Target summary
#  저번에 샀던 곳에서 부드럽고 맛있는 족발을 아빠도 먹게 큰 것으로 시켰다
#
# Text #식음료# 족발시킴 잘햇다 아빠도 좀 먹게 큰거시키지 #@시스템#사진# 얍 부드럽나 맛잇니 옙 어디꺼긔 저번에샀던뎈 오늘른 포장 못하겟어서 걍 배달시킴
# ----------------------------------------------------------------------------------------------------
#
# idx_34000
#
# Summary after
#  씨그램이라는 탄산수에 3가지 맛이 있는데 그중 라임 맛을 제일 좋아한다
#
# Target summary
#  씨그램 탄산수 중에 라임 맛을 좋아하고 코카콜라 회사인데 엘지가 코카콜라를 인수했다고 한다
#
# Text #식음료# 씨그램이라는 탄산수에요 3가지맛이 있는데 저는 라임맛을 제일 좋아하죠 그거 코카콜라꺼 였네요 네 맞아요 엘지가 인수했잖아요 코카콜라 그건 몰랐던 사실인데요 정말이에요 네 꽤 오래되었는데 잘모르시더라고요 2007년도에 인수했어요
# ----------------------------------------------------------------------------------------------------
#
# idx_34100
#
# Summary after
#  집에 수박이 너무 넘쳐나는데 다 먹어가면 사지 말고 있어주겠다고 하니 잘라간다고 한다
#
# Target summary
#  집에 수박이 많이 남아 토요일에 잘라가기로 했다
#
# Text #식음료# 수박 남았니 우리집에 너무 넘쳐나는데 다 먹어가면 사지말고 있어주겠니 잘라갈겡 토요일에 생각보다 금방 안먹어져 아니 한통 겨우 다먹고 이제 한통 잘라는데 엄마가 반통남았었다고 하고 아빠가 화천놀러갔다가 안먹고 수박 그대로 다시 가져왔엉 브엥 그래 가쟈왘
# ----------------------------------------------------------------------------------------------------
#
# idx_34200
#
# Summary after
#  뭘 먹을지 정한다면 오랜만에 밥버거를 먹거나 오랜만에 순두부를 먹는다
#
# Target summary
#  밥버거 또는 순두부찌개를 먹자고 한다
#
# Text #식음료# 뭘먹을지 정한다면 밥버거 각이다 오 밥버거 먹고 오랫만에 키 그래 젱 가까운둣 아니면 오랫만에 순두부 찌개먹어도 좋아 왜야면 오늘 현금엤음 쓰봉산다고 돈 뽑음
# ----------------------------------------------------------------------------------------------------
#
# idx_34300
#
# Summary after
#  카페에서 음료를 시킬 때 얼음을 적게 달라고 하면 된다
#
# Target summary
#  카페에서 음료를 더 많이 먹는 방법은 얼음을 조금 넣어달라고 말하면 된다
#
# Text #식음료# 카페에서 음료시킬때 음료를 더 많이 먹을 수 있는 방법 아나 아니 모르는데 음료 시킬때 얼음을 적게 달라고 하면 돼 아 진짜 얼음양 조절해서 주문할 수 있나 응 얼음양 조절해서 주문 가능하니까 얼음 적게 해서 주문하면 음료 양이 더 많아짐
# ----------------------------------------------------------------------------------------------------
#
# idx_34400
#
# Summary after
#  디디를 지금 예약하려고 9시 배달을 해달라고 애들한테 이야기해버렸다
#
# Target summary
#  아이들이 양념도 잘 먹는 디디치킨을 시키기로 했다
#
# Text #식음료# 디디먹을까 지금예약하게 9시배달해달라고 애들한테 치킨을얘기해버림 빨리답해 어케 시켜말어 시켸 안매운걸로 디디시킬건데 거기양념도애들잘먹어 굿
# ----------------------------------------------------------------------------------------------------
#
# idx_34500
#
# Summary after
#  와플대학에 입학하고 싶다고 하자 맛있는 와플을 공부한답시고 먹고 만들고 싶다고 한다
#
# Target summary
#  와플을 공부한다 하고 먹고 만들고 싶다고 와플 대학에 입학하고 싶다고 한다
#
# Text #식음료# 와플대학에 입학하고 싶어 왜야 맛있는 와플을 공부한답치구 먹고 만들고 언닌느 너가 입학을 안해서 다행이라고 생각해 우힛 그 만들고 먹고 먹고 먹고가 너였으면 어떡해 그럴 일은 없오
# ----------------------------------------------------------------------------------------------------
#
# idx_34600
#
# Summary after
#  대추 과자를 타오바오에서 시키려는 것 같은데 마트에 파는데 보내준 사진이랑 똑같다
#
# Target summary
#  타오바오에서 대추 과자를 시키려는 것 같은데 그거랑 비슷한 걸 마트에서 판다고 말한다
#
# Text #식음료# #@이름# #@이름#가 그거 대추과자 타오바오에서 시키려는거 같은데 그거 마트에 파는데 너가 보내준 사진이랑 똑같은건 없다규 응웅 괜찮아 #@이모티콘# 비슷한건 있다구 고러던뎅 비슷한거 사면 돼 어차피 대추 안에 호두 끝
# ----------------------------------------------------------------------------------------------------
#
# idx_34700
#
# Summary after
#  치킨이 먹고 싶지만 다이어트를 해야 하니 조금만 참자고 한다
#
# Target summary
#  치킨이 먹고 싶다고 말하면서 프라이드에 맥주 한잔하면 좋다면서 못 먹어서 한이라고 말한다
#
# Text #식음료# 치킨먹고싶다 안된다 다이어트해야지 조금만 참자 그래 후라이드에 맥주 한잔하고 집가서 자면 지리긴하는데그치 기름기 쫙빼주세요 하고 하 그때 그치킨 맛있긴하던데 #@이모티콘# 그니까 그때 많이 못먹어서 약간 한이 생긴거같아 #@이모티콘# 살이냐 치킨이냐
# ----------------------------------------------------------------------------------------------------
#
# idx_34800
#
# Summary after
#  용가리는 급식 때 빼고는 먹어본 적이 없는 것 같다
#
# Target summary
#  용가리는 급식 때 빼고 먹어본 적이 없는 거 같다고 하였다
#
# Text #식음료# 용가리는 진짜 옛날에 만이먹었지 진짜 나는 급식때 빼고는 먹어본적이 없는듯 맨날 엄마가 줬 느데 오 참된어머니 셨네
# ----------------------------------------------------------------------------------------------------
#
# idx_34900
#
# Summary after
#  그릭 요구르트에 꿀을 넣으니 너무 달지 않고 맛있다
#
# Target summary
#  그릭요거트에 꿀 넣어서 먹으니 진짜 맛있다
#
# Text #식음료# 그릭요거트 맛있당 지금 요거트먹어 응 요거트에 꿀 넣으니까 진짜 맛있어 너무 달지 않아 안달고 맛있어 많이 먹어 네 서방님
# ----------------------------------------------------------------------------------------------------
#
# idx_35000
#
# Summary after
#  닭갈비가 맛있어서 요즘 내 메뉴 선택은 죽이다
#
# Target summary
#  아깐 먹기 싫다고 했지만 닭갈비 맛있었으며 역시 너의 선택은 최고이고 볶음밥도 최고라고 한다
#
# Text #식음료# 닭갈비 맛있었다 맛나맛나 그티웅 아깐 먹기 싫다더니 역시 너의 선택 최고엿어 요즘 내 메뉴선택 죽이지 응응 볶음밥도 채고 맛있었어
# ----------------------------------------------------------------------------------------------------
